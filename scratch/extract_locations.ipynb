# %%
"""
# Extract and plot latitude/longitude coordinates of locations extracted from text

## Data
Book title: *Up the Amazon and Madeira rivers, through Bolivia and Peru*
Author: *Edward D. Mathews*
Publication date: *1879*

## Terms
- `region of interest` (`roi`): The areas of Peru, Bolivia and Brazil (exlcuding other references that appear in the text to locations e.g. London, China, India)
- `text_chronological`: The chronological appearence of locations in the text
- `journey_chronological`: The chronologcical appearance of locations during the exploration
- `sentence_block`: <= 5 sentence block centred on the possible location reference in the text

## Pipeline
1. Extract and basic clean text
2. Perform NLP on text
3. Identify possible references to locations in the NLP'ed text
4. Fuzzy match possible locations and correct
4. Create dataset of chronologically (in terms of the text) ordered locations with their `sentence_blocks`.
5. Do some fancy opneai api call thingy on the `sentence_blocks`, to see get structured data from the blocks:
    - Is this a real location, or did the NLP make a mistake?
    - Is this location in the region of interest `roi`?
    - Is this location `journey_chronological`?
6. Plot the real locations in the `roi` on a satellite/cartoon map of Brazil using folium
"""
# Out:
# "\n# Extract and plot latitude/longitude coordinates of locations extracted from text\n\n## Data\nBook title: *Up the Amazon and Madeira rivers, through Bolivia and Peru*\nAuthor: *Edward D. Mathews*\nPublication date: *1879*\n\n## Terms\n- `region of interest` (`roi`): The areas of Peru, Bolivia and Brazil (exlcuding other references that appear in the text to locations e.g. London, China, India)\n- `text_chronological`: The chronological appearence of locations in the text\n- `journey_chronological`: The chronologcical appearance of locations during the exploration\n- `sentence_block`: <= 5 sentence block centred on the possible location reference in the text\n\n## Pipeline\n1. Extract and basic clean text\n2. Perform NLP on text\n3. Identify possible references to locations in the NLP'ed text\n4. Fuzzy match possible locations and correct\n4. Create dataset of chronologically (in terms of the text) ordered locations with their `sentence_blocks`.\n5. Do some fancy opneai api call thingy on the `sentence_blocks`, to see get structured data from the blocks:\n    - Is this a real location, or did the NLP make a mistake?\n    - Is this location in the region of interest `roi`?\n    - Is this location `journey_chronological`?\n6. Plot the real locations in the `roi` on a satellite/cartoon map of Brazil using folium\n"

# %%
import os
import numpy as np
import pandas as pd
import re
import json
import random
import time

from collections import Counter

import spacy
import nltk
from nltk.tokenize import sent_tokenize

from rapidfuzz import fuzz

import folium
import matplotlib.pyplot as plt

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut

import geopandas as gpd

from openai import OpenAI

# %%
# Download punkt tokenizer if not already done
nltk.download('punkt', quiet=True)

# Load spaCy model
nlp = spacy.load("en_core_web_trf")

#####
# FILE PATH SETUP (adjust as needed)
TEXT_FILENAME = "Up the Amazon and Madeira Rivers through Bolivia and Peru copy.txt"
COORDS_FILENAME = "coords.json"

CWD = os.getcwd()

PATH_TO_RAW_DATA_DIR = os.path.join(CWD, "data", "raw")
PATH_TO_PROCESSED_DATA_DIR = os.path.join(CWD, "data", "processed")

PATH_TO_DATA = os.path.join(PATH_TO_RAW_DATA_DIR, TEXT_FILENAME)
PATH_TO_COORDS_JSON = os.path.join(PATH_TO_PROCESSED_DATA_DIR, COORDS_FILENAME)

# -- Read the input text
with open(PATH_TO_DATA, 'r') as file:
    text = file.read().replace('\n', ' ')

#####
# Build a list of words and their character offsets
matches = list(re.finditer(r'\S+', text))
words = [m.group(0) for m in matches]
word_starts = [m.start() for m in matches]
word_ends = [m.end() for m in matches]

#####
# Helper function: Find word index for a char position
def find_word_idx(char_idx, starts):
    for i, s in enumerate(starts):
        if char_idx < s:
            return max(i-1, 0)
    return len(starts)-1

#####
# Run spaCy NER
doc = nlp(text)

# Extract (location_text, start_char, end_char) for locations
location_spans = [
    (ent.text, ent.start_char, ent.end_char)
    for ent in doc.ents
    if ent.label_ in ("GPE", "LOC")
]

# %%
sentences = list(doc.sents)
for i in range(10):
    print(f"sentence index {i}: {sentences[i]}\n")
# Out:
# sentence index 0: ##### FRONTMATTER REDACTED #####  PREFACE.
#
# sentence index 1:
#
# sentence index 2: A few years ago I was Resident Engineer of the projected Madeira and Mamoré Railway, to be constructed in the Province of Matto Grosso, in the Empire of Brazil, and as nearly as possible in the centre of the Continent of South America.
#
# sentence index 3: From various causes the prosecution of the enterprise fell into abeyance for some considerable time.
#
# sentence index 4: When the works were temporarily stopped, several reasons combined to induce me to return home by way of Bolivia and Peru.
#
# sentence index 5: During that journey I kept up my ordinary custom of keeping a rough diary, and I have since dressed up my notes into something of a consecutive form.
#
# sentence index 6: The resumption of the railway works has led me to think that some interest would attach to a description of a route across South America that has yet been but little travelled over.
#
# sentence index 7: It has also occurred to me, that nowadays, when the Eastern trip to India, China, Japan, and home _viâ_ San Francisco and New York, has been done by so many there may be adventurous spirits in search of new worlds to conquer, who would be pleased to know of a journey offering the combined attractions of canoeing on the magnificent affluents of the Amazon and a journey in the saddle across the Andes.
#
# sentence index 8: My endeavour therefore has been to give all the information in my possession regarding the method and expense of travelling over the route indicated.
#
# sentence index 9:  In grateful remembrance of many kindnesses received, I have dedicated my labours to the indefatigable worker who, for many years past, has devoted his life to the noble enterprise of opening a way to the markets of Europe for the many and varied products of the Republic of Bolivia and the Province of Matto Grosso in the Empire of Brazil.

# %%
sentence_char_starts = [sent.start_char for sent in sentences]
sentence_char_ends = [sent.end_char for sent in sentences]

# %%
for loc_text, start_char, end_char in location_spans:
    # Find which sentence contains the entity
    containing_sent_idx = None
    for i, (s, e) in enumerate(zip(sentence_char_starts, sentence_char_ends)):
        if start_char >= s and end_char <= e:
            containing_sent_idx = i
            break
    if containing_sent_idx is None:
        continue  # skip if not found (shouldn't really happen)

window = 2  # or whatever context you want
s0 = max(containing_sent_idx - window, 0)
s1 = min(containing_sent_idx + window + 1, len(sentences))
block_sentences = sentences[s0:s1]

block_text = text[sentence_char_starts[s0]:sentence_char_ends[s1-1]]

# To highlight, replace in that substring:
# (this is safer than entity_words variant)
block_text = block_text.replace(loc_text, f"<<{loc_text}>>", 1)

blocks.append({
    'location': loc_text,
    'sentence_block': block_text,
    'sentence_indices': (s0, s1-1),
    'location_start_char': start_char,
    'location_end_char': end_char
})

# %%
#####
# Build blocks (word windowed, guaranteed to contain full location)
window = 30 * 2  # words before and after

blocks = []
for loc_text, start_char, end_char in location_spans:
    start_word_idx = find_word_idx(start_char, word_starts)
    end_word_idx = find_word_idx(end_char-1, word_starts)
    w0 = max(start_word_idx - window, 0)
    w1 = min(end_word_idx + window + 1, len(words))  # +1 so slice includes last word

    block_words = words[w0:w1]
    # For possible highlighting, join the entity words
    entity_words = words[start_word_idx:end_word_idx+1]
    entity_str = ' '.join(entity_words)

    # Optional: mark the location in the block
    sentence_block = ' '.join(block_words)
    # Try to only mark first occurrence so as not to mess with repeated mentions in block
    sentence_block = sentence_block.replace(entity_str, f"<<{entity_str}>>", 1)

    blocks.append({
        'location': loc_text,
        'sentence_block': sentence_block,
        'start_word_index': start_word_idx,
        'end_word_index': end_word_idx,
        'location_start_char': start_char,
        'location_end_char': end_char
    })

df_blocks = pd.DataFrame(blocks)

# %%
def highlight_places_in_text(text, ents, start_char=0, end_char=1000):
    """
    text: full string
    ents: list of spacy entities (doc.ents)
    start_char, end_char: char positions of the slice to show
    """
    # Only consider entities in the given text slice
    display_ents = [e for e in ents if e.end_char > start_char and e.start_char < end_char and e.label_ in ('GPE', 'LOC')]
    # Sort entities so later ones don't disrupt char positions of earlier ones
    display_ents = sorted(display_ents, key=lambda e: e.start_char)
    new_text = text[start_char:end_char]
    offset = 0  # because we will insert stuff, index will shift right
    for ent in display_ents:
        rel_start = ent.start_char - start_char + offset
        rel_end = ent.end_char - start_char + offset
        # Only mark if it's within our slice
        if 0 <= rel_start < len(new_text) and 0 < rel_end <= len(new_text):
            new_text = (
                new_text[:rel_start] +
                f"<<{new_text[rel_start:rel_end]}>>" +
                new_text[rel_end:]
            )
            offset += 4  # len("<<>>")=4 extra chars per entity found
    print(new_text)

# Example use: print the first 1000 characters, highlighting all found places
highlight_places_in_text(text, doc.ents, start_char=0, end_char=5000)
# Out:
# ##### FRONTMATTER REDACTED #####  PREFACE.  A few years ago I was Resident Engineer of the projected Madeira and Mamoré Railway, to be constructed in the Province of <<Matto Grosso>>, in the Empire of <<Brazil>>, and as nearly as possible in the centre of <<the Continent of South America>>. From various causes the prosecution of the enterprise fell into abeyance for some considerable time. When the works were temporarily stopped, several reasons combined to induce me to return home by way of <<Bolivia>> and <<Peru>>. During that journey I kept up my ordinary custom of keeping a rough diary, and I have since dressed up my notes into something of a consecutive form. The resumption of the railway works has led me to think that some interest would attach to a description of a route across <<South America>> that has yet been but little travelled over. It has also occurred to me, that nowadays, when the Eastern trip to <<India>>, <<China>>, <<Japan>>, and home _viâ_ <<San Francisco>> and <<New York>>, has been done by so many there may be adventurous spirits in search of new worlds to conquer, who would be pleased to know of a journey offering the combined attractions of canoeing on the magnificent affluents of the <<Amazon>> and a journey in the saddle across the <<Andes>>. My endeavour therefore has been to give all the information in my possession regarding the method and expense of travelling over the route indicated.  In grateful remembrance of many kindnesses received, I have dedicated my labours to the indefatigable worker who, for many years past, has devoted his life to the noble enterprise of opening a way to the markets of <<Europe>> for the many and varied products of <<the Republic of Bolivia>> and the Province of <<Matto Grosso>> in the Empire of <<Brazil>>.  ##### CONTENTS REDACTED #####  ##### LIST OF ENGRAVINGS REDACTED #####  UP THE <<AMAZON>> AND <<MADEIRA RIVERS>>.  CHAPTER I.      Brazilian coast—True and false <<Salinas>>—Dangers of the mouth of     the <<Amazon>>—<<Pará>>—Steamers on the Amazon—Amazon Steam Shipping     Company, Limited—Vicinity of <<Pará>>—European residents—Climate.   After about twenty days’ steaming from <<Liverpool>> with southerly and westerly courses, the low-lying coast of the north of <<Brazil>> appears, and navigators who are not acquainted with the locality have considerable trouble in making out the pilot station of the <<Salinas>>.  The false Salinas are about half a day’s steam to the east of the true, which, again, are a few hours’ steam from the mouth of <<the Amazon River>>. At the true <<Salinas>> there is a lighthouse and a small village, a large red house, visible from the deck of the steamer, being the barrack in which the pilots for <<Pará>> live.  The steamer in which I had a passage had been chartered specially for the conveyance of the railway staff to which I belonged. The captain knew nothing at all of the spot to which he had undertaken to navigate his ship, and took the vessel considerably to the east of the <<Salinas>>; we were therefore a night and a day coasting about in soundings. At dark, a slight gale gave the sea the most phosphorescent appearance that, in the course of a good many voyages, I have yet seen. Every wave, as it curled over, broke in vivid phosphorescent fire, and it appeared as though we were steaming through a sea of flaming spirits.  The mouth of the river <<Amazon>> has many shifting banks and reefs of which no accurate information exists, and vessels are frequently lost in attempting to get up to <<Pará>> without a pilot. In 1873, three vessels, laden with iron for the <<Madeira>> and <<Mamoré>> railway, were lost, one after another, on the reefs near the <<Braganza>> lightship, which had shifted from her moorings and remained away from her station for many months. More pilots are required at the station of <<Salinas>>, for it has often happened that captains of vessels have got tired of beating about, waiting for a pilot to come off, and h ...

# %%
SIMILARITY_THRESHOLD = 90  # tune as needed

# 1. Gather unique location names
all_locations = [block['location'] for block in blocks]

clusters = []
canonical_names = []
for loc in all_locations:
    matched = False
    for i, canon in enumerate(canonical_names):
        score = fuzz.token_sort_ratio(loc, canon)
        if score >= SIMILARITY_THRESHOLD:
            clusters[i].append(loc)
            matched = True
            break
    if not matched:
        canonical_names.append(loc)
        clusters.append([loc])

# 2. For each cluster, pick a canonical name (most common)
for i, c in enumerate(clusters):
    most_common = Counter(c).most_common(1)[0][0]
    canonical_names[i] = most_common

# --- STEP 3: Build your mapping and annotate blocks afterwards
location_to_canon = {}
for canon, members in zip(canonical_names, clusters):
    for m in members:
        location_to_canon[m] = canon

# Assign canonical_location to each block
for block in blocks:
    block['canonical_location'] = location_to_canon[block['location']]

# %%
locations = [block["canonical_location"] for block in blocks]
print(len(blocks))
print(len(locations))
print(len(set(locations)))
# Out:
# 2417
# 2417
# 506

# %%
# Example output: Print a few blocks
for i in range(len(df_blocks)):  # adjust as you wish
    row = df_blocks.iloc[i]
    if row["location"] == "Cachimayo":
        print('-'*60)
        print("Location:", row["location"])
        print("Block:")
        print(row["sentence_block"])
        print(" ")
# To save: df_blocks.to_csv('location_blocks.csv')
# Out:
# ------------------------------------------------------------
# Location: Cachimayo
# Block:
# the posta which marks the end of the day’s work in good temper, inclined to do good justice to whatever is forthcoming for the nightly repast, after which the thoroughly earned rest is heartily enjoyed both by masters, men, and animals. CHAPTER XXVII. Leave Sucre under escort of English residents—Village of Nutshucc—Yotala—“Quintas,” or farmhouses—Don Tomas Frias’ country-house—Señor Pacheco’s quinta—The river <<Cachimayo>> and its basket bridge—Fever at Nutshucc—The river Pilcomayo—Terrado and Pampa-tambo—Quebrada Honda—Bartolo—Potosí—The Soroche—The Fonda Coca—The Cerro de Potosí—Silver mines—Reservoirs—Church of La Matriz—The mint—New coinage—Burying money—Future of mining in Potosí—Departure from Potosí—Tarapaya—Yocalla—Yocalla bridge built by the devil in a night—Leñas—Loss of my aneroid barometer—Vicuñas—Condors—Lagunillas—Tolapalca—Bolivian Norfolk-Howards, or Vinchutas—Vilcapujio—Curious custom of Indian women—Llamas and alpacas—Ancacata—The pampa of Aullagas—The “Chulpas”—Catariri, Pazna and Poopo—Miserable appearance of
#
# ------------------------------------------------------------
# Location: Cachimayo
# Block:
# Frias’s requirements were on as limited a scale as his country house in the Cachimayo valley, the country could not have suffered much from him personally. Yet, although he was a man of most modest and unambitious desires, his minister of war, Daza, made up in show and extravagance for his leader’s economy. At Nutshucc the ford of the river <<Cachimayo,>> which must be crossed by travellers to or from Potosí, is very frequently impassable. On the Sucre side stands the handsomest villa residence in Bolivia, the property of Don Gregorio Pacheco, who, I believe, has also made his fortune in silver mining, which seems to be the only occupation in Bolivia that leads to affluence. The house is well built,
#
# ------------------------------------------------------------
# Location: Cachimayo
# Block:
# also made his fortune in silver mining, which seems to be the only occupation in Bolivia that leads to affluence. The house is well built, of stone, with a stucco front, having a spacious corridor supported on well-proportioned pillars; the whole arrangement being very comfortable, and the owner is proud of it accordingly. On our arrival we found that the <<Cachimayo>> was coming down in flood, we had therefore to leave our animals at Señor Pacheco’s, and cross the river, about eighty yards in width, in a basket bridge, the property and invention of Señor Pacheco, and therefore universally considered to be a most marvellous and clever enterprise. The river is spanned by a stout rope hawser, about three inches in
#
# ------------------------------------------------------------
# Location: Cachimayo
# Block:
# mid-stream until he can be rescued from the unpleasant position by an acrobatic performance of an Indian, who has to go out on the hawser with a new hauling rope. Nutshucc is considered a very charming place by the Chuquisaquenos, who think it the height of luxury to be the owner of a quinta in the narrow ravine of the <<Cachimayo;>> but although it is pretty by contrast to the dreary plain in which Sucre stands, I did not think it at all equal to some of the environs of Cochabamba. The hills on either side of the Cachimayo ravine are of a shaly rock, which crumbles down in regular slopes with a uniformly dull and heavy look, that quite take
#
# ------------------------------------------------------------
# Location: Cachimayo
# Block:
# the Chuquisaquenos, who think it the height of luxury to be the owner of a quinta in the narrow ravine of the <<Cachimayo>>; but although it is pretty by contrast to the dreary plain in which Sucre stands, I did not think it at all equal to some of the environs of Cochabamba. The hills on either side of the Cachimayo ravine are of a shaly rock, which crumbles down in regular slopes with a uniformly dull and heavy look, that quite take away any idea of the picturesqueness which the valley might have, were the rocks of a more solid character. My experience of the place was not altogether pleasant, for on my first visit there I was taken with

# %%
def get_location_coords(location_set, verbose=False):
    # Filter out None or empty/whitespace locations early
    location_set = set(filter(lambda x: x and x.strip(), location_set))

    geolocator = Nominatim(user_agent="generic_name")
    location_coord_dict = {}
    n_locations = len(location_set)

    t0 = time.perf_counter()
    for count, location in enumerate(location_set, start=1):
        t1 = time.perf_counter()
        print(f"Getting coords for '{location}'; {count}/{n_locations}")
        try:
            loc = geolocator.geocode(location)
            if loc is not None:
                coords = (loc.latitude, loc.longitude)
                print(f"  {location}: {coords}")
                location_coord_dict[location] = coords
            else:
                print(f"  Location not found: {location}")
        except GeocoderUnavailable as e:
            if verbose:
                print(f"  Geocoder is unavailable: {e}")
            else:
                print("  Geocoder is unavailable")
        except GeocoderTimedOut as e:
            if verbose:
                print(f"  Geocoder timed out: {e}")
            else:
                print("  Geocoder timed out")
        except AttributeError as e:
            if verbose:
                print(f"  Attribute error (possibly bad result) for '{location}': {e}")
            else:
                print("  Attribute error (possibly bad result) for '{location}'")
                
        t_elapsed = time.perf_counter() - t1
        total_elapsed = time.perf_counter() - t0
        print(f"  Time for this location: {t_elapsed:.2f} s\n")
        print(f"  Runtime so far: {total_elapsed:.2f} s\n")

    t_total = time.perf_counter() - t0
    print(f"Total time for all locations: {t_total:.2f} s")
    return location_coord_dict

coords_dict = get_location_coords(set(locations))
# Out:
# Getting coords for 'Mamoré'; 1/458
#   Mamoré: (-13.4129427, -65.2152448)
#   Time for this location: 0.19 s
#
#   Runtime so far: 0.19 s
#
# Getting coords for 'Magdalena'; 2/458
#   Geocoder is unavailable
#   Time for this location: 3.14 s
#
#   Runtime so far: 3.33 s
#
# Getting coords for 'COCHABAMBA'; 3/458
#   COCHABAMBA: (-17.4012458, -66.1675681)
#   Time for this location: 0.97 s
#
#   Runtime so far: 4.29 s
#
# Getting coords for 'Venezuela'; 4/458
#   Venezuela: (8.0018709, -66.1109318)
#   Time for this location: 1.93 s
#
#   Runtime so far: 6.22 s
#
# Getting coords for 'Matocari'; 5/458
#   Location not found: Matocari
#   Time for this location: 1.96 s
#
#   Runtime so far: 8.18 s
#
# Getting coords for 'the Rio Grande'; 6/458
#   the Rio Grande: (42.4891061, -2.4409022)
#   Time for this location: 3.07 s
#
#   Runtime so far: 11.26 s
#
# Getting coords for 'Australia'; 7/458
#   Australia: (-24.7761086, 134.755)
#   Time for this location: 2.05 s
#
#   Runtime so far: 13.30 s
#
# Getting coords for 'Madeira'; 8/458
#   Madeira: (32.7517501, -16.9817487)
#   Time for this location: 2.05 s
#
#   Runtime so far: 15.35 s
#
# Getting coords for 'Desaguadero'; 9/458
#   Desaguadero: (-16.564809, -69.0401545)
#   Time for this location: 0.84 s
#
#   Runtime so far: 16.19 s
#
# Getting coords for 'Lima'; 10/458
#   Lima: (-12.0621065, -77.0365256)
#   Time for this location: 3.00 s
#
#   Runtime so far: 19.20 s
#
# Getting coords for 'Panamá'; 11/458
#   Panamá: (8.559559, -81.1308434)
#   Time for this location: 2.05 s
#
#   Runtime so far: 21.24 s
#
# Getting coords for 'Andean'; 12/458
#   Andean: (42.9414286, -7.9979985)
#   Time for this location: 0.97 s
#
#   Runtime so far: 22.21 s
#
# Getting coords for 'Sepulturas'; 13/458
#   Sepulturas: (-17.9769226, -67.0134118)
#   Time for this location: 0.97 s
#
#   Runtime so far: 23.18 s
#
# Getting coords for 'the Amazon River'; 14/458
#   Location not found: the Amazon River
#   Time for this location: 3.13 s
#
#   Runtime so far: 26.31 s
#
# Getting coords for 'Mollendo'; 15/458
#   Mollendo: (-17.0292533, -72.0155447)
#   Time for this location: 0.92 s
#
#   Runtime so far: 27.23 s
#
# Getting coords for 'Columbus'; 16/458
#   Columbus: (39.9622601, -83.0007065)
#   Time for this location: 2.05 s
#
#   Runtime so far: 29.28 s
#
# Getting coords for 'Girão'; 17/458
#   Girão: (32.7351665, -17.1952761)
#   Time for this location: 0.92 s
#
#   Runtime so far: 30.20 s
#
# Getting coords for 'Minas Maio'; 18/458
#   Minas Maio: (-20.316193, -40.4387467)
#   Time for this location: 2.00 s
#
#   Runtime so far: 32.20 s
#
# Getting coords for 'China'; 19/458
#   China: (35.0000663, 104.999955)
#   Time for this location: 3.00 s
#
#   Runtime so far: 35.21 s
#
# Getting coords for 'Gurupá'; 20/458
#   Gurupá: (-1.406325, -51.6427456)
#   Time for this location: 1.97 s
#
#   Runtime so far: 37.18 s
#
# Getting coords for 'Praia'; 21/458
#   Praia: (14.9162811, -23.5095095)
#   Time for this location: 2.00 s
#
#   Runtime so far: 39.18 s
#
# Getting coords for 'United States'; 22/458
#   United States: (39.7837304, -100.445882)
#   Time for this location: 3.10 s
#
#   Runtime so far: 42.28 s
#
# Getting coords for 'Madeira Rivers'; 23/458
#   Madeira Rivers: (-6.8064866, -62.4115491)
#   Time for this location: 3.10 s
#
#   Runtime so far: 45.38 s
#
# Getting coords for 'St. James'; 24/458
#   St. James: (39.573173, -77.7493708)
#   Time for this location: 0.86 s
#
#   Runtime so far: 46.24 s
#
# Getting coords for 'CARIPUNAS'; 25/458
#   CARIPUNAS: (-9.2149237, -64.6514359)
#   Time for this location: 0.94 s
#
#   Runtime so far: 47.18 s
#
# Getting coords for 'Yotala'; 26/458
#   Yotala: (-19.1616017, -65.2647648)
#   Time for this location: 1.00 s
#
#   Runtime so far: 48.18 s
#
# Getting coords for 'the Yacuma River'; 27/458
#   Location not found: the Yacuma River
#   Time for this location: 2.05 s
#
#   Runtime so far: 50.23 s
#
# Getting coords for 'Santa Cruz de la Sierra'; 28/458
#   Santa Cruz de la Sierra: (-17.7834217, -63.1820853)
#   Time for this location: 2.05 s
#
#   Runtime so far: 52.27 s
#
# Getting coords for 'Caracas'; 29/458
#   Caracas: (10.5060934, -66.9146008)
#   Time for this location: 0.97 s
#
#   Runtime so far: 53.24 s
#
# Getting coords for 'Mont Alegre'; 30/458
#   Mont Alegre: (39.6847152, -0.4251072)
#   Time for this location: 2.05 s
#
#   Runtime so far: 55.29 s
#
# Getting coords for 'Borja'; 31/458
#   Borja: (41.8348235, -1.5337542)
#   Time for this location: 0.95 s
#
#   Runtime so far: 56.23 s
#
# Getting coords for 'Mojeño'; 32/458
#   Mojeño: (-14.8781418, -65.5272056)
#   Time for this location: 0.95 s
#
#   Runtime so far: 57.18 s
#
# Getting coords for 'Rio Grande'; 33/458
#   Rio Grande: (29.74434, -102.67467)
#   Time for this location: 3.13 s
#
#   Runtime so far: 60.31 s
#
# Getting coords for 'the Purus Rivers'; 34/458
#   Location not found: the Purus Rivers
#   Time for this location: 2.05 s
#
#   Runtime so far: 62.35 s
#
# Getting coords for 'Chimoré'; 35/458
#   Chimoré: (-16.9939202, -65.1504578)
#   Time for this location: 0.92 s
#
#   Runtime so far: 63.28 s
#
# Getting coords for 'the “Cachuela de Madeira'; 36/458
#   Location not found: the “Cachuela de Madeira
#   Time for this location: 2.05 s
#
#   Runtime so far: 65.32 s
#
# Getting coords for 'Araras'; 37/458
#   Araras: (-22.3569192, -47.3838766)
#   Time for this location: 0.92 s
#
#   Runtime so far: 66.25 s
#
# Getting coords for 'Ribeirão'; 38/458
#   Ribeirão: (-8.5066761, -35.3747339)
#   Time for this location: 1.95 s
#
#   Runtime so far: 68.19 s
#
# Getting coords for 'Misque'; 39/458
#   Misque: (-37.1616846, -72.4707556)
#   Time for this location: 2.05 s
#
#   Runtime so far: 70.24 s
#
# Getting coords for 'the Pacific seaboard'; 40/458
#   Location not found: the Pacific seaboard
#   Time for this location: 2.05 s
#
#   Runtime so far: 72.29 s
#
# Getting coords for 'Andes'; 41/458
#   Andes: (5.6555942, -75.8778448)
#   Time for this location: 2.05 s
#
#   Runtime so far: 74.33 s
#
# Getting coords for 'the Cliza valley'; 42/458
#   Location not found: the Cliza valley
#   Time for this location: 0.92 s
#
#   Runtime so far: 75.26 s
#
# Getting coords for 'Quevedo'; 43/458
#   Quevedo: (-1.0669701, -79.4776812)
#   Time for this location: 1.96 s
#
#   Runtime so far: 77.22 s
#
# Getting coords for 'UT'; 44/458
#   UT: (39.4225192, -111.714358)
#   Time for this location: 2.03 s
#
#   Runtime so far: 79.25 s
#
# Getting coords for 'Beni'; 45/458
#   Beni: (9.5293472, 2.2584408)
#   Time for this location: 2.05 s
#
#   Runtime so far: 81.30 s
#
# Getting coords for 'Masa Cruz'; 46/458
#   Masa Cruz: (41.6539246, -4.7219655)
#   Time for this location: 0.93 s
#
#   Runtime so far: 82.23 s
#
# Getting coords for 'Santa Ana—“Mani'; 47/458
#   Santa Ana—“Mani: (-2.8876186, -79.0325895)
#   Time for this location: 2.03 s
#
#   Runtime so far: 84.26 s
#
# Getting coords for 'Payta'; 48/458
#   Payta: (19.4926425, -99.1337776)
#   Time for this location: 1.96 s
#
#   Runtime so far: 86.22 s
#
# Getting coords for 'the United States'; 49/458
#   the United States: (47.8291375, -122.5970742)
#   Time for this location: 3.07 s
#
#   Runtime so far: 89.29 s
#
# Getting coords for 'the Republic of Chili'; 50/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 92.45 s
#
# Getting coords for 'Sancho Mundo'; 51/458
#   Sancho Mundo: (26.9452559, -105.7054322)
#   Time for this location: 0.94 s
#
#   Runtime so far: 93.38 s
#
# Getting coords for 'Jamaica'; 52/458
#   Jamaica: (18.1850507, -77.3947693)
#   Time for this location: 0.92 s
#
#   Runtime so far: 94.31 s
#
# Getting coords for 'Bananeiras'; 53/458
#   Bananeiras: (-6.7537682, -35.6338343)
#   Time for this location: 0.92 s
#
#   Runtime so far: 95.23 s
#
# Getting coords for 'Sajáma'; 54/458
#   Sajáma: (-18.108263, -68.6023775)
#   Time for this location: 0.97 s
#
#   Runtime so far: 96.19 s
#
# Getting coords for 'the Serra dos Parentins'; 55/458
#   Location not found: the Serra dos Parentins
#   Time for this location: 3.13 s
#
#   Runtime so far: 99.32 s
#
# Getting coords for 'Hindostan'; 56/458
#   Hindostan: (22.3511148, 78.6677428)
#   Time for this location: 0.92 s
#
#   Runtime so far: 100.24 s
#
# Getting coords for 'Totora'; 57/458
#   Totora: (-6.4927301, -77.4719348)
#   Time for this location: 2.05 s
#
#   Runtime so far: 102.29 s
#
# Getting coords for 'Quebrada Honda'; 58/458
#   Quebrada Honda: (10.1875824, -85.297654)
#   Time for this location: 1.95 s
#
#   Runtime so far: 104.24 s
#
# Getting coords for 'the Gran Chaco'; 59/458
#   Location not found: the Gran Chaco
#   Time for this location: 2.05 s
#
#   Runtime so far: 106.28 s
#
# Getting coords for 'Larati'; 60/458
#   Larati: (-17.3442383, -66.0119337)
#   Time for this location: 1.95 s
#
#   Runtime so far: 108.23 s
#
# Getting coords for 'Chulancani'; 61/458
#   Location not found: Chulancani
#   Time for this location: 1.95 s
#
#   Runtime so far: 110.18 s
#
# Getting coords for 'Europe'; 62/458
#   Europe: (51.0, 10.0)
#   Time for this location: 2.05 s
#
#   Runtime so far: 112.22 s
#
# Getting coords for 'Malaga'; 63/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 115.37 s
#
# Getting coords for 'Rio de la Plata'; 64/458
#   Rio de la Plata: (-35.13352, -56.2743702)
#   Time for this location: 0.95 s
#
#   Runtime so far: 116.32 s
#
# Getting coords for 'Colon'; 65/458
#   Colon: (41.2974531, -96.6094912)
#   Time for this location: 0.94 s
#
#   Runtime so far: 117.26 s
#
# Getting coords for 'London'; 66/458
#   London: (51.5074456, -0.1277653)
#   Time for this location: 0.92 s
#
#   Runtime so far: 118.18 s
#
# Getting coords for 'Cobija'; 67/458
#   Cobija: (-11.0184614, -68.7538149)
#   Time for this location: 2.03 s
#
#   Runtime so far: 120.21 s
#
# Getting coords for 'Pisco'; 68/458
#   Pisco: (-13.7099813, -76.2029793)
#   Time for this location: 2.05 s
#
#   Runtime so far: 122.26 s
#
# Getting coords for 'Eastern Bolivia'; 69/458
#   Eastern Bolivia: (45.4211595, -75.6970477)
#   Time for this location: 0.98 s
#
#   Runtime so far: 123.24 s
#
# Getting coords for 'France'; 70/458
#   France: (46.603354, 1.8883335)
#   Time for this location: 1.96 s
#
#   Runtime so far: 125.20 s
#
# Getting coords for 'Tarata'; 71/458
#   Tarata: (-17.3983215, -69.9913225)
#   Time for this location: 1.00 s
#
#   Runtime so far: 126.20 s
#
# Getting coords for 'Punata'; 72/458
#   Punata: (-17.5926818, -65.8496605)
#   Time for this location: 1.99 s
#
#   Runtime so far: 128.20 s
#
# Getting coords for 'Boa Vista'; 73/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 131.36 s
#
# Getting coords for 'Sará'; 74/458
#   Geocoder is unavailable
#   Time for this location: 3.22 s
#
#   Runtime so far: 134.58 s
#
# Getting coords for 'Cavinas'; 75/458
#   Cavinas: (-12.6272626, -66.770274)
#   Time for this location: 0.69 s
#
#   Runtime so far: 135.27 s
#
# Getting coords for 'the Bolivian Andes'; 76/458
#   Location not found: the Bolivian Andes
#   Time for this location: 2.99 s
#
#   Runtime so far: 138.26 s
#
# Getting coords for 'Vio'; 77/458
#   Vio: (42.9086546, 12.9191449)
#   Time for this location: 1.00 s
#
#   Runtime so far: 139.26 s
#
# Getting coords for 'Plymouth'; 78/458
#   Plymouth: (50.3714122, -4.1424451)
#   Time for this location: 3.08 s
#
#   Runtime so far: 142.33 s
#
# Getting coords for 'Choro'; 79/458
#   Choro: (-4.8435726, -39.1393071)
#   Time for this location: 0.86 s
#
#   Runtime so far: 143.20 s
#
# Getting coords for 'Chapari'; 80/458
#   Chapari: (24.8625456, 87.6380734)
#   Time for this location: 0.98 s
#
#   Runtime so far: 144.18 s
#
# Getting coords for 'Las Piedras de Uruás'; 81/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 147.33 s
#
# Getting coords for 'Itonama'; 82/458
#   Itonama: (-12.9664704, -63.4872592)
#   Time for this location: 0.94 s
#
#   Runtime so far: 148.27 s
#
# Getting coords for 'Poplar'; 83/458
#   Poplar: (51.5110713, -0.0144629)
#   Time for this location: 1.94 s
#
#   Runtime so far: 150.21 s
#
# Getting coords for 'Corrientes'; 84/458
#   Corrientes: (-28.9956512, -57.812458)
#   Time for this location: 2.05 s
#
#   Runtime so far: 152.26 s
#
# Getting coords for 'Parainha'; 85/458
#   Location not found: Parainha
#   Time for this location: 0.92 s
#
#   Runtime so far: 153.19 s
#
# Getting coords for 'El Carmen'; 86/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 156.35 s
#
# Getting coords for 'Chili'; 87/458
#   Chili: (-31.7613365, -71.3187697)
#   Time for this location: 0.88 s
#
#   Runtime so far: 157.23 s
#
# Getting coords for 'the Beni valley'; 88/458
#   Location not found: the Beni valley
#   Time for this location: 2.04 s
#
#   Runtime so far: 159.26 s
#
# Getting coords for 'Llollia'; 89/458
#   Location not found: Llollia
#   Time for this location: 0.99 s
#
#   Runtime so far: 160.25 s
#
# Getting coords for 'Macacos'; 90/458
#   Macacos: (-23.5001413, -48.1908444)
#   Time for this location: 2.05 s
#
#   Runtime so far: 162.30 s
#
# Getting coords for 'the Lingua Geral'; 91/458
#   Location not found: the Lingua Geral
#   Time for this location: 0.92 s
#
#   Runtime so far: 163.22 s
#
# Getting coords for 'Asuncion'; 92/458
#   Geocoder is unavailable
#   Time for this location: 3.17 s
#
#   Runtime so far: 166.38 s
#
# Getting coords for 'Matto Grosso'; 93/458
#   Matto Grosso: (-15.269921, -66.769053)
#   Time for this location: 0.83 s
#
#   Runtime so far: 167.21 s
#
# Getting coords for 'the Republic of Bolivia'; 94/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 170.37 s
#
# Getting coords for 'Santarem'; 95/458
#   Santarem: (39.2363637, -8.6867081)
#   Time for this location: 0.94 s
#
#   Runtime so far: 171.31 s
#
# Getting coords for 'Tarija'; 96/458
#   Tarija: (-21.583333, -63.833333)
#   Time for this location: 0.92 s
#
#   Runtime so far: 172.23 s
#
# Getting coords for 'the Province'; 97/458
#   the Province: (35.6023347, -77.3695595)
#   Time for this location: 2.05 s
#
#   Runtime so far: 174.28 s
#
# Getting coords for 'the Lower Madeira'; 98/458
#   the Lower Madeira: (50.7578962, -1.5392597)
#   Time for this location: 1.95 s
#
#   Runtime so far: 176.23 s
#
# Getting coords for 'Trinidad'; 99/458
#   Trinidad: (10.4430243, -61.2613054)
#   Time for this location: 3.08 s
#
#   Runtime so far: 179.31 s
#
# Getting coords for 'Bayetas'; 100/458
#   Location not found: Bayetas
#   Time for this location: 0.91 s
#
#   Runtime so far: 180.22 s
#
# Getting coords for 'England'; 101/458
#   England: (52.5310214, -1.2649062)
#   Time for this location: 3.08 s
#
#   Runtime so far: 183.30 s
#
# Getting coords for 'the “Street of the Shore'; 102/458
#   the “Street of the Shore: (55.9749858, -3.1668986)
#   Time for this location: 0.98 s
#
#   Runtime so far: 184.28 s
#
# Getting coords for 'Izozo'; 103/458
#   Izozo: (-17.2357172, -64.5224947)
#   Time for this location: 0.96 s
#
#   Runtime so far: 185.24 s
#
# Getting coords for 'Pará'; 104/458
#   Pará: (-6.8699697, -75.0458515)
#   Time for this location: 2.05 s
#
#   Runtime so far: 187.28 s
#
# Getting coords for 'The Bay of Theotonio'; 105/458
#   Location not found: The Bay of Theotonio
#   Time for this location: 2.00 s
#
#   Runtime so far: 189.29 s
#
# Getting coords for 'Esmeralda'; 106/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 192.44 s
#
# Getting coords for 'Copiapo'; 107/458
#   Copiapo: (-27.3664685, -70.3322753)
#   Time for this location: 0.78 s
#
#   Runtime so far: 193.22 s
#
# Getting coords for 'farinha'; 108/458
#   farinha: (-5.3879592, -45.418489)
#   Time for this location: 2.05 s
#
#   Runtime so far: 195.27 s
#
# Getting coords for 'La     '; 109/458
#   La     : (20.0171109, 103.378253)
#   Time for this location: 0.92 s
#
#   Runtime so far: 196.19 s
#
# Getting coords for 'Machupa'; 110/458
#   Machupa: (-6.169784, 39.211856)
#   Time for this location: 1.00 s
#
#   Runtime so far: 197.20 s
#
# Getting coords for 'Mojos'; 111/458
#   Mojos: (-14.9961581, -65.641067)
#   Time for this location: 2.02 s
#
#   Runtime so far: 199.22 s
#
# Getting coords for 'the Rocks of Uruás'; 112/458
#   Location not found: the Rocks of Uruás
#   Time for this location: 3.12 s
#
#   Runtime so far: 202.34 s
#
# Getting coords for 'Caracoles'; 113/458
#   Caracoles: (-34.421071, -70.9391069)
#   Time for this location: 0.92 s
#
#   Runtime so far: 203.26 s
#
# Getting coords for 'Yungas'; 114/458
#   Yungas: (-16.3997857, -72.1648294)
#   Time for this location: 0.93 s
#
#   Runtime so far: 204.19 s
#
# Getting coords for 'the San Mateo'; 115/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 207.34 s
#
# Getting coords for 'the West Indies'; 116/458
#   the West Indies: (50.836359, 0.4617891)
#   Time for this location: 0.94 s
#
#   Runtime so far: 208.28 s
#
# Getting coords for 'Aymará'; 117/458
#   Aymará: (-34.5852492, -58.380157)
#   Time for this location: 0.93 s
#
#   Runtime so far: 209.20 s
#
# Getting coords for 'Potosí'; 118/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 212.36 s
#
# Getting coords for 'Cayubaba'; 119/458
#   Cayubaba: (-13.3195647, -65.2507884)
#   Time for this location: 0.94 s
#
#   Runtime so far: 213.29 s
#
# Getting coords for 'Obidos'; 120/458
#   Obidos: (39.3619514, -9.157153)
#   Time for this location: 1.95 s
#
#   Runtime so far: 215.24 s
#
# Getting coords for 'the Andean Mountains'; 121/458
#   Location not found: the Andean Mountains
#   Time for this location: 2.01 s
#
#   Runtime so far: 217.25 s
#
# Getting coords for 'Manicoré'; 122/458
#   Manicoré: (-5.804618, -61.289483)
#   Time for this location: 0.96 s
#
#   Runtime so far: 218.21 s
#
# Getting coords for 'Tacora'; 123/458
#   Tacora: (-19.8744967, -66.2268456)
#   Time for this location: 1.98 s
#
#   Runtime so far: 220.19 s
#
# Getting coords for 'Guajará Merim'; 124/458
#   Location not found: Guajará Merim
#   Time for this location: 2.02 s
#
#   Runtime so far: 222.20 s
#
# Getting coords for 'AMAZON'; 125/458
#   AMAZON: (-0.6207328, -51.5756469)
#   Time for this location: 2.05 s
#
#   Runtime so far: 224.25 s
#
# Getting coords for 'Great Britain'; 126/458
#   Great Britain: (54.3151594, -1.9181532)
#   Time for this location: 1.95 s
#
#   Runtime so far: 226.20 s
#
# Getting coords for 'Exaltacion'; 127/458
#   Exaltacion: (-11.7890104, -66.9367974)
#   Time for this location: 2.05 s
#
#   Runtime so far: 228.24 s
#
# Getting coords for 'BOLIVIA'; 128/458
#   BOLIVIA: (-17.0568696, -64.9912286)
#   Time for this location: 2.01 s
#
#   Runtime so far: 230.25 s
#
# Getting coords for 'Maravilla'; 129/458
#   Maravilla: (34.0332976, -118.1681507)
#   Time for this location: 1.98 s
#
#   Runtime so far: 232.24 s
#
# Getting coords for 'Caripuna'; 130/458
#   Caripuna: (-23.2971765, -46.0387037)
#   Time for this location: 2.05 s
#
#   Runtime so far: 234.29 s
#
# Getting coords for 'Cosepilla'; 131/458
#   Location not found: Cosepilla
#   Time for this location: 0.92 s
#
#   Runtime so far: 235.21 s
#
# Getting coords for 'Misericordia'; 132/458
#   Misericordia: (38.7114084, -9.1507477)
#   Time for this location: 3.07 s
#
#   Runtime so far: 238.28 s
#
# Getting coords for 'El Cerro del Volcan'; 133/458
#   El Cerro del Volcan: (13.5402156, -86.2128568)
#   Time for this location: 3.12 s
#
#   Runtime so far: 241.39 s
#
# Getting coords for 'Cerrito'; 134/458
#   Cerrito: (-31.8546304, -52.8151659)
#   Time for this location: 0.85 s
#
#   Runtime so far: 242.24 s
#
# Getting coords for 'San Ignacio'; 135/458
#   San Ignacio: (-5.1243684, -78.8956299)
#   Time for this location: 1.00 s
#
#   Runtime so far: 243.24 s
#
# Getting coords for 'Plate'; 136/458
#   Plate: (53.5499214, 11.4999932)
#   Time for this location: 3.13 s
#
#   Runtime so far: 246.37 s
#
# Getting coords for 'Coni'; 137/458
#   Coni: (44.4580703, 7.5581367)
#   Time for this location: 0.92 s
#
#   Runtime so far: 247.29 s
#
# Getting coords for 'Arequipa'; 138/458
#   Arequipa: (-16.3988667, -71.5369607)
#   Time for this location: 0.99 s
#
#   Runtime so far: 248.28 s
#
# Getting coords for 'Apolobamba'; 139/458
#   Apolobamba: (-15.0237542, -68.9035868)
#   Time for this location: 0.91 s
#
#   Runtime so far: 249.19 s
#
# Getting coords for 'Pocona'; 140/458
#   Pocona: (-17.6747701, -65.4199602)
#   Time for this location: 0.98 s
#
#   Runtime so far: 250.18 s
#
# Getting coords for 'Atlantic'; 141/458
#   Atlantic: (39.5143268, -74.6632883)
#   Time for this location: 2.03 s
#
#   Runtime so far: 252.21 s
#
# Getting coords for 'Manáos'; 142/458
#   Manáos: (-3.1316333, -59.9825041)
#   Time for this location: 2.05 s
#
#   Runtime so far: 254.25 s
#
# Getting coords for 'Curahuara'; 143/458
#   Curahuara: (-17.6322495, -67.986774)
#   Time for this location: 1.95 s
#
#   Runtime so far: 256.20 s
#
# Getting coords for 'Pacaguaras'; 144/458
#   Location not found: Pacaguaras
#   Time for this location: 0.99 s
#
#   Runtime so far: 257.19 s
#
# Getting coords for 'The Falls of Pao Grande'; 145/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 260.34 s
#
# Getting coords for 'Borba'; 146/458
#   Borba: (38.8057942, -7.4542105)
#   Time for this location: 0.98 s
#
#   Runtime so far: 261.32 s
#
# Getting coords for 'Paz'; 147/458
#   Paz: (45.2908372, 14.0944912)
#   Time for this location: 0.90 s
#
#   Runtime so far: 262.22 s
#
# Getting coords for 'Silver Hill'; 148/458
#   Silver Hill: (38.839849, -76.9381785)
#   Time for this location: 1.95 s
#
#   Runtime so far: 264.18 s
#
# Getting coords for 'the Madeira and'; 149/458
#   the Madeira and: (51.6064776, -0.5563306)
#   Time for this location: 2.06 s
#
#   Runtime so far: 266.24 s
#
# Getting coords for 'Amazonas'; 150/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 269.39 s
#
# Getting coords for 'CHUQUISACA'; 151/458
#   CHUQUISACA: (-19.0477251, -65.2594306)
#   Time for this location: 0.83 s
#
#   Runtime so far: 270.23 s
#
# Getting coords for 'Catamarca'; 152/458
#   Catamarca: (-27.1910825, -67.105374)
#   Time for this location: 2.05 s
#
#   Runtime so far: 272.28 s
#
# Getting coords for 'Gran Chaco'; 153/458
#   Gran Chaco: (-20.0976312, -59.8739161)
#   Time for this location: 0.92 s
#
#   Runtime so far: 273.20 s
#
# Getting coords for 'Cuatro Ojos'; 154/458
#   Cuatro Ojos: (41.6921754, -3.9773195)
#   Time for this location: 2.05 s
#
#   Runtime so far: 275.25 s
#
# Getting coords for 'Merim'; 155/458
#   Merim: (42.0467658, -8.4003247)
#   Time for this location: 1.97 s
#
#   Runtime so far: 277.21 s
#
# Getting coords for 'Japan'; 156/458
#   Japan: (36.5748441, 139.2394179)
#   Time for this location: 2.03 s
#
#   Runtime so far: 279.24 s
#
# Getting coords for 'Rapids'; 157/458
#   Rapids: (43.0957985, -78.6545955)
#   Time for this location: 2.05 s
#
#   Runtime so far: 281.29 s
#
# Getting coords for 'the Madeira Falls'; 158/458
#   Location not found: the Madeira Falls
#   Time for this location: 1.93 s
#
#   Runtime so far: 283.22 s
#
# Getting coords for 'Maddalena'; 159/458
#   Maddalena: (45.0293003, 7.3023687)
#   Time for this location: 2.06 s
#
#   Runtime so far: 285.28 s
#
# Getting coords for 'the Island of Araras'; 160/458
#   Location not found: the Island of Araras
#   Time for this location: 2.05 s
#
#   Runtime so far: 287.33 s
#
# Getting coords for 'Nutshucc'; 161/458
#   Location not found: Nutshucc
#   Time for this location: 0.92 s
#
#   Runtime so far: 288.25 s
#
# Getting coords for 'San Francisco'; 162/458
#   San Francisco: (37.7792588, -122.4193286)
#   Time for this location: 0.98 s
#
#   Runtime so far: 289.23 s
#
# Getting coords for 'Guajará-guasu'; 163/458
#   Location not found: Guajará-guasu
#   Time for this location: 0.96 s
#
#   Runtime so far: 290.20 s
#
# Getting coords for 'Matto'; 164/458
#   Matto: (36.5266411, 136.5661935)
#   Time for this location: 2.05 s
#
#   Runtime so far: 292.24 s
#
# Getting coords for 'the Chagres River'; 165/458
#   Location not found: the Chagres River
#   Time for this location: 2.05 s
#
#   Runtime so far: 294.29 s
#
# Getting coords for 'Yaci Paraná'; 166/458
#   Location not found: Yaci Paraná
#   Time for this location: 2.05 s
#
#   Runtime so far: 296.34 s
#
# Getting coords for 'Curumbá'; 167/458
#   Curumbá: (-23.3496199, -47.6303565)
#   Time for this location: 0.88 s
#
#   Runtime so far: 297.23 s
#
# Getting coords for 'Liverpool'; 168/458
#   Liverpool: (53.4071991, -2.99168)
#   Time for this location: 3.07 s
#
#   Runtime so far: 300.30 s
#
# Getting coords for 'Yocalla'; 169/458
#   Yocalla: (-19.3888592, -65.9112948)
#   Time for this location: 0.88 s
#
#   Runtime so far: 301.18 s
#
# Getting coords for 'La Cruz'; 170/458
#   La Cruz: (11.0088428, -85.5518491)
#   Time for this location: 3.05 s
#
#   Runtime so far: 304.23 s
#
# Getting coords for 'Valparaiso'; 171/458
#   Valparaiso: (41.4672552, -87.0604487)
#   Time for this location: 2.05 s
#
#   Runtime so far: 306.27 s
#
# Getting coords for 'the Atlantic Ocean'; 172/458
#   the Atlantic Ocean: (62.46558, 6.0960324)
#   Time for this location: 2.05 s
#
#   Runtime so far: 308.32 s
#
# Getting coords for 'San Nicolas'; 173/458
#   San Nicolas: (16.0703505, 120.7624714)
#   Time for this location: 2.05 s
#
#   Runtime so far: 310.37 s
#
# Getting coords for 'Old Castile'; 174/458
#   Location not found: Old Castile
#   Time for this location: 0.92 s
#
#   Runtime so far: 311.29 s
#
# Getting coords for 'Brobdignagia'; 175/458
#   Location not found: Brobdignagia
#   Time for this location: 0.87 s
#
#   Runtime so far: 312.17 s
#
# Getting coords for 'Catariri'; 176/458
#   Catariri: (-19.7357903, -66.9563811)
#   Time for this location: 3.12 s
#
#   Runtime so far: 315.28 s
#
# Getting coords for 'Paraguay'; 177/458
#   Paraguay: (-23.3165935, -58.1693445)
#   Time for this location: 1.95 s
#
#   Runtime so far: 317.23 s
#
# Getting coords for 'the Black Country'; 178/458
#   the Black Country: (52.5215006, -2.0766606)
#   Time for this location: 0.99 s
#
#   Runtime so far: 318.23 s
#
# Getting coords for 'Tacna'; 179/458
#   Tacna: (-18.01386, -70.2511032)
#   Time for this location: 1.97 s
#
#   Runtime so far: 320.20 s
#
# Getting coords for 'La Paz'; 180/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 323.35 s
#
# Getting coords for 'Los Jocotales'; 181/458
#   Location not found: Los Jocotales
#   Time for this location: 0.83 s
#
#   Runtime so far: 324.18 s
#
# Getting coords for 'La Barca'; 182/458
#   La Barca: (44.083538, 10.4444778)
#   Time for this location: 3.08 s
#
#   Runtime so far: 327.27 s
#
# Getting coords for 'Argentine'; 183/458
#   Argentine: (-34.9964963, -64.9672817)
#   Time for this location: 2.05 s
#
#   Runtime so far: 329.31 s
#
# Getting coords for 'San José'; 184/458
#   San José: (37.3361663, -121.890591)
#   Time for this location: 1.94 s
#
#   Runtime so far: 331.25 s
#
# Getting coords for 'Canichana'; 185/458
#   Canichana: (-14.1817047, -65.0243059)
#   Time for this location: 1.95 s
#
#   Runtime so far: 333.21 s
#
# Getting coords for 'Sucre'; 186/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 336.37 s
#
# Getting coords for 'Deseada'; 187/458
#   Deseada: (28.5692311, -17.8372084)
#   Time for this location: 0.83 s
#
#   Runtime so far: 337.20 s
#
# Getting coords for 'Maury'; 188/458
#   Maury: (35.6285992, -87.0736684)
#   Time for this location: 0.99 s
#
#   Runtime so far: 338.19 s
#
# Getting coords for 'Spain'; 189/458
#   Spain: (39.3260685, -4.8379791)
#   Time for this location: 3.11 s
#
#   Runtime so far: 341.30 s
#
# Getting coords for 'the Straits of Magellan'; 190/458
#   Location not found: the Straits of Magellan
#   Time for this location: 0.95 s
#
#   Runtime so far: 342.26 s
#
# Getting coords for 'LLOLLIA'; 191/458
#   Location not found: LLOLLIA
#   Time for this location: 0.98 s
#
#   Runtime so far: 343.24 s
#
# Getting coords for 'Chuquisaca'; 192/458
#   Chuquisaca: (-19.0477251, -65.2594306)
#   Time for this location: 1.95 s
#
#   Runtime so far: 345.19 s
#
# Getting coords for 'Birkenhead'; 193/458
#   Birkenhead: (53.3895177, -3.0248007)
#   Time for this location: 2.05 s
#
#   Runtime so far: 347.23 s
#
# Getting coords for 'Apiri'; 194/458
#   Apiri: (1.7851613, 33.4015272)
#   Time for this location: 2.05 s
#
#   Runtime so far: 349.28 s
#
# Getting coords for 'Peru'; 195/458
#   Peru: (-6.8699697, -75.0458515)
#   Time for this location: 2.05 s
#
#   Runtime so far: 351.33 s
#
# Getting coords for 'the Cuesta de Malaga'; 196/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 354.49 s
#
# Getting coords for 'Las Tetillas'; 197/458
#   Las Tetillas: (12.5284007, -86.238356)
#   Time for this location: 0.73 s
#
#   Runtime so far: 355.22 s
#
# Getting coords for 'Curahuara de Carangas'; 198/458
#   Curahuara de Carangas: (-17.8426585, -68.4089744)
#   Time for this location: 1.97 s
#
#   Runtime so far: 357.19 s
#
# Getting coords for 'Amazon'; 199/458
#   Amazon: (-0.6207328, -51.5756469)
#   Time for this location: 3.05 s
#
#   Runtime so far: 360.24 s
#
# Getting coords for 'Valle Grande'; 200/458
#   Valle Grande: (-23.4767516, -64.9460176)
#   Time for this location: 1.95 s
#
#   Runtime so far: 362.19 s
#
# Getting coords for 'Pamas'; 201/458
#   Pamas: (-2.8507408, -78.337884)
#   Time for this location: 2.04 s
#
#   Runtime so far: 364.23 s
#
# Getting coords for 'Calamarca'; 202/458
#   Calamarca: (-8.1700672, -78.4115144)
#   Time for this location: 2.05 s
#
#   Runtime so far: 366.28 s
#
# Getting coords for 'Pachia'; 203/458
#   Pachia: (45.8253865, 26.1180463)
#   Time for this location: 0.92 s
#
#   Runtime so far: 367.20 s
#
# Getting coords for 'the Yungas of Espiritu Santo'; 204/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 370.36 s
#
# Getting coords for 'Yocclia'; 205/458
#   Location not found: Yocclia
#   Time for this location: 0.83 s
#
#   Runtime so far: 371.20 s
#
# Getting coords for 'the Cachimayo valley'; 206/458
#   Location not found: the Cachimayo valley
#   Time for this location: 2.01 s
#
#   Runtime so far: 373.20 s
#
# Getting coords for 'Guajarás'; 207/458
#   Guajarás: (36.9123213, -3.7450558)
#   Time for this location: 1.97 s
#
#   Runtime so far: 375.17 s
#
# Getting coords for 'Vacas'; 208/458
#   Vacas: (18.153532, -66.4756856)
#   Time for this location: 2.06 s
#
#   Runtime so far: 377.24 s
#
# Getting coords for 'Orinoco'; 209/458
#   Orinoco: (7.6328194, -64.8599339)
#   Time for this location: 0.95 s
#
#   Runtime so far: 378.19 s
#
# Getting coords for 'U.S.'; 210/458
#   U.S.: (39.7837304, -100.445882)
#   Time for this location: 3.04 s
#
#   Runtime so far: 381.23 s
#
# Getting coords for 'Guajará     Guasu'; 211/458
#   Location not found: Guajará     Guasu
#   Time for this location: 2.05 s
#
#   Runtime so far: 383.28 s
#
# Getting coords for 'Poopo'; 212/458
#   Poopo: (-18.2505991, -66.9746906)
#   Time for this location: 0.91 s
#
#   Runtime so far: 384.19 s
#
# Getting coords for 'Southampton'; 213/458
#   Southampton: (50.9025349, -1.404189)
#   Time for this location: 2.06 s
#
#   Runtime so far: 386.25 s
#
# Getting coords for 'New York'; 214/458
#   New York: (40.7127281, -74.0060152)
#   Time for this location: 2.05 s
#
#   Runtime so far: 388.30 s
#
# Getting coords for 'Guasu'; 215/458
#   Guasu: (54.3151594, -1.9181532)
#   Time for this location: 0.92 s
#
#   Runtime so far: 389.22 s
#
# Getting coords for 'Pacific'; 216/458
#   Pacific: (46.5334929, -123.768029)
#   Time for this location: 2.05 s
#
#   Runtime so far: 391.27 s
#
# Getting coords for 'the Mamoré River'; 217/458
#   Location not found: the Mamoré River
#   Time for this location: 2.00 s
#
#   Runtime so far: 393.27 s
#
# Getting coords for 'Titicaca'; 218/458
#   Titicaca: (-15.7334907, -69.9357769)
#   Time for this location: 0.93 s
#
#   Runtime so far: 394.20 s
#
# Getting coords for 'Maués'; 219/458
#   Maués: (-3.3795798, -57.7196072)
#   Time for this location: 0.99 s
#
#   Runtime so far: 395.18 s
#
# Getting coords for 'the Madeira River'; 220/458
#   Location not found: the Madeira River
#   Time for this location: 3.08 s
#
#   Runtime so far: 398.27 s
#
# Getting coords for 'the Girão Falls'; 221/458
#   Location not found: the Girão Falls
#   Time for this location: 0.94 s
#
#   Runtime so far: 399.20 s
#
# Getting coords for 'Yaci-Paraná'; 222/458
#   Location not found: Yaci-Paraná
#   Time for this location: 2.03 s
#
#   Runtime so far: 401.24 s
#
# Getting coords for 'SAN ANTONIO'; 223/458
#   SAN ANTONIO: (29.4246002, -98.4951405)
#   Time for this location: 2.00 s
#
#   Runtime so far: 403.24 s
#
# Getting coords for 'Calcutta'; 224/458
#   Calcutta: (22.5726459, 88.3638953)
#   Time for this location: 0.97 s
#
#   Runtime so far: 404.21 s
#
# Getting coords for 'Breves'; 225/458
#   Breves: (-1.68036, -50.479085)
#   Time for this location: 0.97 s
#
#   Runtime so far: 405.18 s
#
# Getting coords for 'TACORA'; 226/458
#   TACORA: (-19.8744967, -66.2268456)
#   Time for this location: 1.00 s
#
#   Runtime so far: 406.17 s
#
# Getting coords for 'San Ramon'; 227/458
#   San Ramon: (37.7648021, -121.9544387)
#   Time for this location: 2.04 s
#
#   Runtime so far: 408.22 s
#
# Getting coords for 'Salinas'; 228/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 411.36 s
#
# Getting coords for 'Layes'; 229/458
#   Layes: (42.4127663, -0.4216246)
#   Time for this location: 0.90 s
#
#   Runtime so far: 412.26 s
#
# Getting coords for 'Sahama'; 230/458
#   Sahama: (-13.24, 15.359167)
#   Time for this location: 1.95 s
#
#   Runtime so far: 414.21 s
#
# Getting coords for 'Tamandoa'; 231/458
#   Location not found: Tamandoa
#   Time for this location: 2.05 s
#
#   Runtime so far: 416.25 s
#
# Getting coords for 'San Louise'; 232/458
#   San Louise: (34.7363227, 135.5097558)
#   Time for this location: 2.05 s
#
#   Runtime so far: 418.30 s
#
# Getting coords for 'Paredão'; 233/458
#   Paredão: (-19.21701, -45.2065915)
#   Time for this location: 0.92 s
#
#   Runtime so far: 419.22 s
#
# Getting coords for 'Santa Ana'; 234/458
#   Santa Ana: (33.7494951, -117.873221)
#   Time for this location: 2.05 s
#
#   Runtime so far: 421.27 s
#
# Getting coords for 'Tombs'; 235/458
#   Tombs: (27.6637328, 30.9276322)
#   Time for this location: 1.92 s
#
#   Runtime so far: 423.19 s
#
# Getting coords for 'Republic'; 236/458
#   Republic: (39.8266503, -97.6580834)
#   Time for this location: 1.00 s
#
#   Runtime so far: 424.19 s
#
# Getting coords for 'Lomas'; 237/458
#   Lomas: (42.27354, -4.5503861)
#   Time for this location: 2.00 s
#
#   Runtime so far: 426.19 s
#
# Getting coords for 'Rabo'; 238/458
#   Rabo: (5.301701, 95.5928614)
#   Time for this location: 2.04 s
#
#   Runtime so far: 428.23 s
#
# Getting coords for 'charqui'; 239/458
#   charqui: (-3.3461686, -79.0312353)
#   Time for this location: 0.94 s
#
#   Runtime so far: 429.18 s
#
# Getting coords for 'Crato'; 240/458
#   Crato: (-7.2369112, -39.4149236)
#   Time for this location: 2.02 s
#
#   Runtime so far: 431.19 s
#
# Getting coords for 'Securé'; 241/458
#   Securé: (-16.1735801, -65.838946)
#   Time for this location: 2.06 s
#
#   Runtime so far: 433.25 s
#
# Getting coords for 'Diaz Gana'; 242/458
#   Diaz Gana: (-23.665188, -70.3949972)
#   Time for this location: 2.05 s
#
#   Runtime so far: 435.30 s
#
# Getting coords for 'West End'; 243/458
#   West End: (35.9099875, -79.0752876)
#   Time for this location: 1.94 s
#
#   Runtime so far: 437.24 s
#
# Getting coords for 'Serpa'; 244/458
#   Serpa: (37.9436517, -7.5966902)
#   Time for this location: 2.05 s
#
#   Runtime so far: 439.29 s
#
# Getting coords for 'El Cerrito'; 245/458
#   El Cerrito: (37.9154056, -122.301411)
#   Time for this location: 1.95 s
#
#   Runtime so far: 441.24 s
#
# Getting coords for 'Patagonia'; 246/458
#   Patagonia: (31.5402016, -110.753927)
#   Time for this location: 3.07 s
#
#   Runtime so far: 444.31 s
#
# Getting coords for 'Cordillera'; 247/458
#   Cordillera: (17.3597101, 121.0716923)
#   Time for this location: 1.95 s
#
#   Runtime so far: 446.26 s
#
# Getting coords for 'Cerro'; 248/458
#   Cerro: (42.2977315, 13.4958871)
#   Time for this location: 0.96 s
#
#   Runtime so far: 447.22 s
#
# Getting coords for 'Atacama'; 249/458
#   Atacama: (-24.5563029, -69.4226479)
#   Time for this location: 0.98 s
#
#   Runtime so far: 448.20 s
#
# Getting coords for 'Tolapalca'; 250/458
#   Tolapalca: (-16.0099371, -70.665549)
#   Time for this location: 0.98 s
#
#   Runtime so far: 449.18 s
#
# Getting coords for 'Callao'; 251/458
#   Callao: (-12.0864633, -77.2234463)
#   Time for this location: 3.11 s
#
#   Runtime so far: 452.30 s
#
# Getting coords for 'Inca Corral'; 252/458
#   Inca Corral: (-17.4222312, -65.9482004)
#   Time for this location: 0.92 s
#
#   Runtime so far: 453.22 s
#
# Getting coords for 'Reyes'; 253/458
#   Reyes: (-14.2952193, -67.335855)
#   Time for this location: 1.97 s
#
#   Runtime so far: 455.19 s
#
# Getting coords for 'Las Siete     '; 254/458
#   Las Siete     : (28.3473425, -16.8928153)
#   Time for this location: 3.04 s
#
#   Runtime so far: 458.24 s
#
# Getting coords for 'San Pedro'; 255/458
#   San Pedro: (33.7358518, -118.2922934)
#   Time for this location: 3.07 s
#
#   Runtime so far: 461.31 s
#
# Getting coords for 'South America'; 256/458
#   South America: (-21.0002179, -61.0006565)
#   Time for this location: 0.92 s
#
#   Runtime so far: 462.23 s
#
# Getting coords for 'the Tapajoz River'; 257/458
#   Location not found: the Tapajoz River
#   Time for this location: 0.96 s
#
#   Runtime so far: 463.19 s
#
# Getting coords for 'Otuquis'; 258/458
#   Otuquis: (-19.609404, -58.2894017)
#   Time for this location: 1.00 s
#
#   Runtime so far: 464.19 s
#
# Getting coords for 'The Beni River'; 259/458
#   Location not found: The Beni River
#   Time for this location: 2.07 s
#
#   Runtime so far: 466.26 s
#
# Getting coords for 'Pilcomayo'; 260/458
#   Pilcomayo: (-12.0493725, -75.2504039)
#   Time for this location: 0.94 s
#
#   Runtime so far: 467.20 s
#
# Getting coords for 'Merceditas'; 261/458
#   Merceditas: (23.0595224, -82.293862)
#   Time for this location: 0.98 s
#
#   Runtime so far: 468.18 s
#
# Getting coords for 'The San Antonio'; 262/458
#   The San Antonio: (43.2533477, -2.8840011)
#   Time for this location: 3.16 s
#
#   Runtime so far: 471.34 s
#
# Getting coords for 'Western Brazil'; 263/458
#   Western Brazil: (-0.1813973, 30.3640168)
#   Time for this location: 0.87 s
#
#   Runtime so far: 472.21 s
#
# Getting coords for 'LIVERPOOL'; 264/458
#   LIVERPOOL: (53.4071991, -2.99168)
#   Time for this location: 2.06 s
#
#   Runtime so far: 474.28 s
#
# Getting coords for 'Oliden'; 265/458
#   Oliden: (-35.1843158, -57.9486525)
#   Time for this location: 0.93 s
#
#   Runtime so far: 475.20 s
#
# Getting coords for 'Alto Peru'; 266/458
#   Alto Peru: (-8.9492072, -78.5798997)
#   Time for this location: 2.08 s
#
#   Runtime so far: 477.28 s
#
# Getting coords for 'Yuracaré'; 267/458
#   Yuracaré: (-16.8928688, -64.7962327)
#   Time for this location: 0.92 s
#
#   Runtime so far: 478.20 s
#
# Getting coords for 'the Bananeiras Falls'; 268/458
#   Location not found: the Bananeiras Falls
#   Time for this location: 2.05 s
#
#   Runtime so far: 480.25 s
#
# Getting coords for 'Prado'; 269/458
#   Prado: (41.9203967, -5.4203949)
#   Time for this location: 2.05 s
#
#   Runtime so far: 482.30 s
#
# Getting coords for 'Chocos'; 270/458
#   Chocos: (-12.927275, -75.9143335)
#   Time for this location: 0.88 s
#
#   Runtime so far: 483.18 s
#
# Getting coords for 'SUCRE'; 271/458
#   SUCRE: (-19.0477251, -65.2594306)
#   Time for this location: 3.12 s
#
#   Runtime so far: 486.31 s
#
# Getting coords for 'Calderão'; 272/458
#   Calderão: (-8.7071664, -36.2583471)
#   Time for this location: 0.91 s
#
#   Runtime so far: 487.22 s
#
# Getting coords for 'Espiritu Santo'; 273/458
#   Espiritu Santo: (-15.1563411, 167.0510705)
#   Time for this location: 2.00 s
#
#   Runtime so far: 489.21 s
#
# Getting coords for 'Portugal'; 274/458
#   Portugal: (39.6621648, -8.1353519)
#   Time for this location: 3.03 s
#
#   Runtime so far: 492.24 s
#
# Getting coords for 'Oruro'; 275/458
#   Oruro: (-18.666667, -67.666667)
#   Time for this location: 2.04 s
#
#   Runtime so far: 494.28 s
#
# Getting coords for 'Cinti'; 276/458
#   Cinti: (39.1014537, -84.5124602)
#   Time for this location: 0.92 s
#
#   Runtime so far: 495.20 s
#
# Getting coords for 'Cliza'; 277/458
#   Cliza: (-17.5918058, -65.9341813)
#   Time for this location: 2.05 s
#
#   Runtime so far: 497.25 s
#
# Getting coords for 'Bahia Negra'; 278/458
#   Bahia Negra: (-20.2308712, -58.1690716)
#   Time for this location: 1.94 s
#
#   Runtime so far: 499.20 s
#
# Getting coords for 'Canto Molino'; 279/458
#   Canto Molino: (43.266554, -5.7439882)
#   Time for this location: 3.07 s
#
#   Runtime so far: 502.27 s
#
# Getting coords for 'Umaitá'; 280/458
#   Umaitá: (-12.0070525, -68.231074)
#   Time for this location: 0.92 s
#
#   Runtime so far: 503.19 s
#
# Getting coords for 'Manchester'; 281/458
#   Manchester: (53.4794892, -2.2451148)
#   Time for this location: 2.05 s
#
#   Runtime so far: 505.24 s
#
# Getting coords for 'Chacomo'; 282/458
#   Location not found: Chacomo
#   Time for this location: 1.93 s
#
#   Runtime so far: 507.16 s
#
# Getting coords for 'Mont     '; 283/458
#   Mont     : (47.3752671, -109.638757)
#   Time for this location: 2.02 s
#
#   Runtime so far: 509.18 s
#
# Getting coords for 'Morinhos'; 284/458
#   Morinhos: (-5.8229709, -47.0732895)
#   Time for this location: 0.99 s
#
#   Runtime so far: 510.18 s
#
# Getting coords for 'the Bay of Biscay O'; 285/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 513.33 s
#
# Getting coords for 'Chilon'; 286/458
#   Chilon: (40.738034, 72.517889)
#   Time for this location: 0.92 s
#
#   Runtime so far: 514.25 s
#
# Getting coords for 'Angostura'; 287/458
#   Angostura: (8.1028532, -63.5469562)
#   Time for this location: 2.05 s
#
#   Runtime so far: 516.30 s
#
# Getting coords for 'Tuy'; 288/458
#   Tuy: (42.0501375, -8.6466411)
#   Time for this location: 0.92 s
#
#   Runtime so far: 517.22 s
#
# Getting coords for 'Islay'; 289/458
#   Islay: (55.7585802, -6.1656723)
#   Time for this location: 2.05 s
#
#   Runtime so far: 519.27 s
#
# Getting coords for 'Guaporé'; 290/458
#   Guaporé: (-28.8471928, -51.8907881)
#   Time for this location: 2.05 s
#
#   Runtime so far: 521.32 s
#
# Getting coords for 'Palca'; 291/458
#   Palca: (-16.5611164, -67.9530221)
#   Time for this location: 0.92 s
#
#   Runtime so far: 522.24 s
#
# Getting coords for 'Hamburg'; 292/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 525.40 s
#
# Getting coords for 'Sandia'; 293/458
#   Sandia: (-13.833333, -69.333333)
#   Time for this location: 0.94 s
#
#   Runtime so far: 526.33 s
#
# Getting coords for 'Taboga'; 294/458
#   Taboga: (8.7895216, -79.56074)
#   Time for this location: 0.85 s
#
#   Runtime so far: 527.18 s
#
# Getting coords for 'Capitan Cinco’s Island'; 295/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 530.34 s
#
# Getting coords for 'San Borja'; 296/458
#   San Borja: (-12.107075, -76.9988421)
#   Time for this location: 0.91 s
#
#   Runtime so far: 531.25 s
#
# Getting coords for 'Blanco River'; 297/458
#   Blanco River: (29.9912476, -98.094547)
#   Time for this location: 1.94 s
#
#   Runtime so far: 533.19 s
#
# Getting coords for 'Loa'; 298/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 536.34 s
#
# Getting coords for 'the Bay of Marajo'; 299/458
#   Location not found: the Bay of Marajo
#   Time for this location: 0.95 s
#
#   Runtime so far: 537.28 s
#
# Getting coords for 'the Rio Negro'; 300/458
#   the Rio Negro: (37.7527574, -0.8423281)
#   Time for this location: 2.05 s
#
#   Runtime so far: 539.34 s
#
# Getting coords for 'the Lake of Valencia'; 301/458
#   Location not found: the Lake of Valencia
#   Time for this location: 1.95 s
#
#   Runtime so far: 541.28 s
#
# Getting coords for 'The Sierra da Paca Nova'; 302/458
#   Location not found: The Sierra da Paca Nova
#   Time for this location: 3.12 s
#
#   Runtime so far: 544.40 s
#
# Getting coords for 'the Cordilheira Geral'; 303/458
#   Location not found: the Cordilheira Geral
#   Time for this location: 0.87 s
#
#   Runtime so far: 545.28 s
#
# Getting coords for 'THE MADEIRA RIVER'; 304/458
#   Location not found: THE MADEIRA RIVER
#   Time for this location: 2.04 s
#
#   Runtime so far: 547.31 s
#
# Getting coords for 'the “Sierra da Paca Nova'; 305/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 550.46 s
#
# Getting coords for 'Purus'; 306/458
#   Purus: (-7.5658532, -66.4654237)
#   Time for this location: 0.73 s
#
#   Runtime so far: 551.19 s
#
# Getting coords for 'San     '; 307/458
#   San     : (7.0000085, -73.2500086)
#   Time for this location: 2.00 s
#
#   Runtime so far: 553.19 s
#
# Getting coords for 'Old England'; 308/458
#   Old England: (50.8428356, 4.3590958)
#   Time for this location: 2.02 s
#
#   Runtime so far: 555.21 s
#
# Getting coords for 'Sapucaia-oroca'; 309/458
#   Location not found: Sapucaia-oroca
#   Time for this location: 0.99 s
#
#   Runtime so far: 556.20 s
#
# Getting coords for 'Chinguri'; 310/458
#   Chinguri: (-18.3840813, -65.2244488)
#   Time for this location: 2.98 s
#
#   Runtime so far: 559.17 s
#
# Getting coords for 'Oran'; 311/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 562.33 s
#
# Getting coords for 'Yata'; 312/458
#   Yata: (-10.4872569, -65.4357103)
#   Time for this location: 0.97 s
#
#   Runtime so far: 563.30 s
#
# Getting coords for 'Loreto'; 313/458
#   Loreto: (43.439498, 13.6070214)
#   Time for this location: 2.05 s
#
#   Runtime so far: 565.35 s
#
# Getting coords for 'Bolivia'; 314/458
#   Bolivia: (-17.0568696, -64.9912286)
#   Time for this location: 0.92 s
#
#   Runtime so far: 566.27 s
#
# Getting coords for 'Buena Esperanza'; 315/458
#   Buena Esperanza: (-34.7578641, -65.2535837)
#   Time for this location: 1.95 s
#
#   Runtime so far: 568.21 s
#
# Getting coords for 'Pederneira'; 316/458
#   Pederneira: (39.6029108, -9.0701572)
#   Time for this location: 0.98 s
#
#   Runtime so far: 569.19 s
#
# Getting coords for 'Caupolican'; 317/458
#   Caupolican: (-2.8946801, -78.9762521)
#   Time for this location: 3.12 s
#
#   Runtime so far: 572.31 s
#
# Getting coords for 'the “Cuesta del Lina Tambo'; 318/458
#   Location not found: the “Cuesta del Lina Tambo
#   Time for this location: 2.01 s
#
#   Runtime so far: 574.32 s
#
# Getting coords for 'San Pablo'; 319/458
#   San Pablo: (-23.5506507, -46.6333824)
#   Time for this location: 0.96 s
#
#   Runtime so far: 575.28 s
#
# Getting coords for 'Central India'; 320/458
#   Central India: (22.5724857, 88.3587427)
#   Time for this location: 1.92 s
#
#   Runtime so far: 577.20 s
#
# Getting coords for 'Central America'; 321/458
#   Central America: (-30.2928485, 153.1256159)
#   Time for this location: 0.98 s
#
#   Runtime so far: 578.18 s
#
# Getting coords for 'Mayosa'; 322/458
#   Mayosa: (-12.5319418, -65.1601508)
#   Time for this location: 1.00 s
#
#   Runtime so far: 579.18 s
#
# Getting coords for 'Aullagas'; 323/458
#   Aullagas: (-18.6822248, -65.9974987)
#   Time for this location: 2.04 s
#
#   Runtime so far: 581.22 s
#
# Getting coords for 'El Cruzero'; 324/458
#   El Cruzero: (11.6944323, -84.4009638)
#   Time for this location: 2.05 s
#
#   Runtime so far: 583.27 s
#
# Getting coords for 'the East Indies'; 325/458
#   the East Indies: (52.7295398, -1.7300896)
#   Time for this location: 2.05 s
#
#   Runtime so far: 585.32 s
#
# Getting coords for 'the Pacific coast'; 326/458
#   the Pacific coast: (38.0186902, -122.7298682)
#   Time for this location: 0.92 s
#
#   Runtime so far: 586.24 s
#
# Getting coords for 'Bartolo'; 327/458
#   Bartolo: (18.2011587, -66.8503643)
#   Time for this location: 2.05 s
#
#   Runtime so far: 588.29 s
#
# Getting coords for 'Cerro de Potosí'; 328/458
#   Cerro de Potosí: (25.6607879, -100.4398121)
#   Time for this location: 0.92 s
#
#   Runtime so far: 589.21 s
#
# Getting coords for 'Cavalho Marinho'; 329/458
#   Cavalho Marinho: (-16.4921664, -39.0736868)
#   Time for this location: 2.00 s
#
#   Runtime so far: 591.20 s
#
# Getting coords for 'Nuestra Señora del Concepcion'; 330/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 594.36 s
#
# Getting coords for 'Quilpa'; 331/458
#   Quilpa: (-6.4863107, -76.3594255)
#   Time for this location: 0.81 s
#
#   Runtime so far: 595.18 s
#
# Getting coords for 'San Carlos'; 332/458
#   San Carlos: (37.504936, -122.261823)
#   Time for this location: 2.05 s
#
#   Runtime so far: 597.23 s
#
# Getting coords for 'the Pacific Coast'; 333/458
#   the Pacific Coast: (38.0186902, -122.7298682)
#   Time for this location: 1.98 s
#
#   Runtime so far: 599.21 s
#
# Getting coords for 'the “Silver Hill of Potosí'; 334/458
#   Location not found: the “Silver Hill of Potosí
#   Time for this location: 3.11 s
#
#   Runtime so far: 602.32 s
#
# Getting coords for 'India'; 335/458
#   India: (22.3511148, 78.6677428)
#   Time for this location: 0.86 s
#
#   Runtime so far: 603.19 s
#
# Getting coords for 'MADEIRA'; 336/458
#   Geocoder is unavailable
#   Time for this location: 3.17 s
#
#   Runtime so far: 606.35 s
#
# Getting coords for 'San Simon'; 337/458
#   San Simon: (32.2665117, -109.2270613)
#   Time for this location: 0.95 s
#
#   Runtime so far: 607.31 s
#
# Getting coords for 'River Tapajoz'; 338/458
#   Location not found: River Tapajoz
#   Time for this location: 0.88 s
#
#   Runtime so far: 608.18 s
#
# Getting coords for 'Siriono'; 339/458
#   Siriono: (-17.3839684, -66.1849123)
#   Time for this location: 1.00 s
#
#   Runtime so far: 609.18 s
#
# Getting coords for 'Ancacata'; 340/458
#   Location not found: Ancacata
#   Time for this location: 0.98 s
#
#   Runtime so far: 610.17 s
#
# Getting coords for 'Quiroga'; 341/458
#   Quiroga: (42.4751472, -7.2697796)
#   Time for this location: 2.08 s
#
#   Runtime so far: 612.25 s
#
# Getting coords for 'Paraná'; 342/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 615.40 s
#
# Getting coords for 'Porco'; 343/458
#   Porco: (37.7252547, -7.8304851)
#   Time for this location: 0.80 s
#
#   Runtime so far: 616.20 s
#
# Getting coords for 'Periquitos'; 344/458
#   Periquitos: (-22.7799785, -43.3268206)
#   Time for this location: 2.98 s
#
#   Runtime so far: 619.18 s
#
# Getting coords for 'janchi'; 345/458
# ...
#
# Getting coords for 'PERU'; 346/458
#   PERU: (-6.8699697, -75.0458515)
#   Time for this location: 3.07 s
#
#   Runtime so far: 624.28 s
#
# Getting coords for 'Vermejo'; 347/458
#   Vermejo: (37.0852054, -116.0538054)
#   Time for this location: 0.97 s
#
#   Runtime so far: 625.25 s
#
# Getting coords for 'Marmélos'; 348/458
#   Marmélos: (41.4309748, -7.202133)
#   Time for this location: 1.95 s
#
#   Runtime so far: 627.20 s
#
# Getting coords for 'the Itenez River'; 349/458
#   Location not found: the Itenez River
#   Time for this location: 2.02 s
#
#   Runtime so far: 629.22 s
#
# Getting coords for 'the River Grande'; 350/458
#   Location not found: the River Grande
#   Time for this location: 2.07 s
#
#   Runtime so far: 631.29 s
#
# Getting coords for 'Sacába'; 351/458
#   Sacába: (-17.320452, -66.0459591)
#   Time for this location: 0.92 s
#
#   Runtime so far: 632.22 s
#
# Getting coords for 'Capitan Cinco’s'; 352/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 635.37 s
#
# Getting coords for 'Cochi'; 353/458
#   Cochi: (-33.4356923, -70.6497111)
#   Time for this location: 0.81 s
#
#   Runtime so far: 636.18 s
#
# Getting coords for 'Tapajoz'; 354/458
#   Tapajoz: (-3.0958776, -60.0583542)
#   Time for this location: 3.10 s
#
#   Runtime so far: 639.28 s
#
# Getting coords for 'Concepcion de Baures'; 355/458
#   Concepcion de Baures: (-16.5497806, -68.1975537)
#   Time for this location: 2.01 s
#
#   Runtime so far: 641.29 s
#
# Getting coords for 'the Continent of South America'; 356/458
#   Location not found: the Continent of South America
#   Time for this location: 3.00 s
#
#   Runtime so far: 644.30 s
#
# Getting coords for 'Cochabamba'; 357/458
#   Cochabamba: (-17.4012458, -66.1675681)
#   Time for this location: 1.95 s
#
#   Runtime so far: 646.25 s
#
# Getting coords for 'the Madeira valley'; 358/458
#   Location not found: the Madeira valley
#   Time for this location: 3.05 s
#
#   Runtime so far: 649.29 s
#
# Getting coords for 'Pazna'; 359/458
#   Pazna: (-18.5974435, -66.9207527)
#   Time for this location: 0.94 s
#
#   Runtime so far: 650.24 s
#
# Getting coords for 'PARÁ'; 360/458
#   PARÁ: (-6.8699697, -75.0458515)
#   Time for this location: 2.05 s
#
#   Runtime so far: 652.29 s
#
# Getting coords for 'Isthmus'; 361/458
#   Isthmus: (35.9981447, -84.1584272)
#   Time for this location: 1.95 s
#
#   Runtime so far: 654.23 s
#
# Getting coords for 'Bella Vista'; 362/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 657.39 s
#
# Getting coords for 'ENGLAND'; 363/458
#   ENGLAND: (52.5310214, -1.2649062)
#   Time for this location: 0.93 s
#
#   Runtime so far: 658.32 s
#
# Getting coords for 'the Trés Irmãos River'; 364/458
#   Location not found: the Trés Irmãos River
#   Time for this location: 2.05 s
#
#   Runtime so far: 660.38 s
#
# Getting coords for 'California'; 365/458
#   California: (36.7014631, -118.755997)
#   Time for this location: 0.92 s
#
#   Runtime so far: 661.30 s
#
# Getting coords for 'Pichagas'; 366/458
#   Location not found: Pichagas
#   Time for this location: 0.87 s
#
#   Runtime so far: 662.17 s
#
# Getting coords for 'Hindoo'; 367/458
#   Hindoo: (49.5548035, -124.9061185)
#   Time for this location: 2.00 s
#
#   Runtime so far: 664.17 s
#
# Getting coords for 'Isla'; 368/458
#   Isla: (35.887175, 14.517307)
#   Time for this location: 2.04 s
#
#   Runtime so far: 666.21 s
#
# Getting coords for 'Tucuman'; 369/458
#   Tucuman: (-26.5643582, -64.882397)
#   Time for this location: 2.05 s
#
#   Runtime so far: 668.26 s
#
# Getting coords for 'Arauna-cuara'; 370/458
#   Location not found: Arauna-cuara
#   Time for this location: 0.97 s
#
#   Runtime so far: 669.23 s
#
# Getting coords for 'Puno'; 371/458
#   Puno: (-15.0, -70.0)
#   Time for this location: 2.00 s
#
#   Runtime so far: 671.23 s
#
# Getting coords for 'Jamucheo'; 372/458
#   Location not found: Jamucheo
#   Time for this location: 0.96 s
#
#   Runtime so far: 672.19 s
#
# Getting coords for 'Callao Bay'; 373/458
#   Callao Bay: (-12.0577778, -77.1552778)
#   Time for this location: 3.14 s
#
#   Runtime so far: 675.33 s
#
# Getting coords for 'the Ribeirão Falls'; 374/458
#   Location not found: the Ribeirão Falls
#   Time for this location: 0.92 s
#
#   Runtime so far: 676.25 s
#
# Getting coords for 'Calara'; 375/458
#   Calara: (6.4517957, 124.790849)
#   Time for this location: 2.05 s
#
#   Runtime so far: 678.30 s
#
# Getting coords for 'Nazareth'; 376/458
#   Nazareth: (32.7046364, 35.2971854)
#   Time for this location: 0.95 s
#
#   Runtime so far: 679.25 s
#
# Getting coords for 'playas'; 377/458
#   playas: (-2.5937913, -80.4261454)
#   Time for this location: 0.99 s
#
#   Runtime so far: 680.24 s
#
# Getting coords for 'the Baure River'; 378/458
#   Location not found: the Baure River
#   Time for this location: 2.05 s
#
#   Runtime so far: 682.29 s
#
# Getting coords for 'Yca'; 379/458
#   Yca: (49.6789457, -124.9806989)
#   Time for this location: 0.92 s
#
#   Runtime so far: 683.21 s
#
# Getting coords for 'Trés Irmãos'; 380/458
#   Trés Irmãos: (-21.6280789, -41.9884844)
#   Time for this location: 1.00 s
#
#   Runtime so far: 684.21 s
#
# Getting coords for 'Amazon Rivers'; 381/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 687.36 s
#
# Getting coords for 'Cristal Maio'; 382/458
#   Cristal Maio: (37.1162032, -8.6560299)
#   Time for this location: 0.97 s
#
#   Runtime so far: 688.33 s
#
# Getting coords for 'Sacta'; 383/458
#   Sacta: (-14.2592937, -75.7009502)
#   Time for this location: 0.92 s
#
#   Runtime so far: 689.25 s
#
# Getting coords for 'Northern Brazil'; 384/458
#   Northern Brazil: (-29.8322441, 17.1613977)
#   Time for this location: 0.96 s
#
#   Runtime so far: 690.21 s
#
# Getting coords for 'Itenez'; 385/458
#   Itenez: (-13.3623488, -63.1872093)
#   Time for this location: 2.01 s
#
#   Runtime so far: 692.22 s
#
# Getting coords for 'Marajo'; 386/458
#   Marajo: (-0.9558821, -49.5469438)
#   Time for this location: 2.05 s
#
#   Runtime so far: 694.27 s
#
# Getting coords for 'Grande'; 387/458
#   Grande: (53.5823287, 10.3863496)
#   Time for this location: 1.94 s
#
#   Runtime so far: 696.21 s
#
# Getting coords for 'San Xavier'; 388/458
#   San Xavier: (32.1036996, -111.013981)
#   Time for this location: 2.05 s
#
#   Runtime so far: 698.26 s
#
# Getting coords for 'El Cerrito”—Small'; 389/458
#   Location not found: El Cerrito”—Small
#   Time for this location: 2.05 s
#
#   Runtime so far: 700.31 s
#
# Getting coords for 'Yacuma'; 390/458
#   Yacuma: (-13.7830746, -65.8903957)
#   Time for this location: 0.92 s
#
#   Runtime so far: 701.23 s
#
# Getting coords for 'Principe da Beira'; 391/458
#   Principe da Beira: (-12.0704497, -64.1866661)
#   Time for this location: 1.96 s
#
#   Runtime so far: 703.19 s
#
# Getting coords for 'Pachimoco'; 392/458
#   Pachimoco: (-30.1979169, -68.8300915)
#   Time for this location: 2.03 s
#
#   Runtime so far: 705.23 s
#
# Getting coords for 'Baures'; 393/458
#   Baures: (-13.6546062, -63.6955015)
#   Time for this location: 2.05 s
#
#   Runtime so far: 707.28 s
#
# Getting coords for 'the “Rabo do Ribeirão'; 394/458
#   Location not found: the “Rabo do Ribeirão
#   Time for this location: 2.07 s
#
#   Runtime so far: 709.35 s
#
# Getting coords for 'Ybari'; 395/458
#   Location not found: Ybari
#   Time for this location: 0.82 s
#
#   Runtime so far: 710.17 s
#
# Getting coords for 'Brazil'; 396/458
#   Brazil: (-10.3333333, -53.2)
#   Time for this location: 3.05 s
#
#   Runtime so far: 713.22 s
#
# Getting coords for 'Charqui'; 397/458
#   Charqui: (-3.3461686, -79.0312353)
#   Time for this location: 2.05 s
#
#   Runtime so far: 715.26 s
#
# Getting coords for 'Santa Cruz'; 398/458
#   Santa Cruz: (28.467178, -16.2507843)
#   Time for this location: 2.00 s
#
#   Runtime so far: 717.26 s
#
# Getting coords for 'Arani'; 399/458
#   Arani: (-17.5996321, -65.6653538)
#   Time for this location: 0.97 s
#
#   Runtime so far: 718.23 s
#
# Getting coords for 'the San Jacinto'; 400/458
#   the San Jacinto: (14.0726309, 121.3254664)
#   Time for this location: 3.13 s
#
#   Runtime so far: 721.36 s
#
# Getting coords for 'a “City of Health'; 401/458
#   a “City of Health: (48.508063, 32.2660465)
#   Time for this location: 2.05 s
#
#   Runtime so far: 723.41 s
#
# Getting coords for 'El Chaco'; 402/458
#   El Chaco: (-0.2442778, -77.675958)
#   Time for this location: 0.87 s
#
#   Runtime so far: 724.27 s
#
# Getting coords for 'Mississippi'; 403/458
#   Mississippi: (32.9715285, -89.7348497)
#   Time for this location: 2.05 s
#
#   Runtime so far: 726.32 s
#
# Getting coords for 'Aspinwall'; 404/458
#   Aspinwall: (41.9120574, -95.1354782)
#   Time for this location: 0.92 s
#
#   Runtime so far: 727.24 s
#
# Getting coords for 'As Penhas Coloradas'; 405/458
#   Location not found: As Penhas Coloradas
#   Time for this location: 2.04 s
#
#   Runtime so far: 729.28 s
#
# Getting coords for 'Machado'; 406/458
#   Machado: (-21.6762861, -45.9211696)
#   Time for this location: 0.91 s
#
#   Runtime so far: 730.19 s
#
# Getting coords for 'Cruzero'; 407/458
#   Cruzero: (-13.3350222, -72.1562292)
#   Time for this location: 2.07 s
#
#   Runtime so far: 732.26 s
#
# Getting coords for 'the Theotonio Fall'; 408/458
#   Location not found: the Theotonio Fall
#   Time for this location: 2.00 s
#
#   Runtime so far: 734.26 s
#
# Getting coords for 'Aiquile'; 409/458
#   Aiquile: (-18.2002218, -65.1806293)
#   Time for this location: 0.97 s
#
#   Runtime so far: 735.23 s
#
# Getting coords for 'Huata'; 410/458
#   Huata: (-9.0161061, -77.8619114)
#   Time for this location: 0.95 s
#
#   Runtime so far: 736.18 s
#
# Getting coords for 'Theotonio'; 411/458
#   Theotonio: (-22.8205701, -43.3616001)
#   Time for this location: 2.02 s
#
#   Runtime so far: 738.20 s
#
# Getting coords for 'remanso'; 412/458
#   remanso: (-9.6179416, -42.0830557)
#   Time for this location: 2.05 s
#
#   Runtime so far: 740.25 s
#
# Getting coords for 'the Chimoré River'; 413/458
#   Location not found: the Chimoré River
#   Time for this location: 2.05 s
#
#   Runtime so far: 742.30 s
#
# Getting coords for 'Leñas'; 414/458
#   Leñas: (-19.2508556, -66.0734544)
#   Time for this location: 0.89 s
#
#   Runtime so far: 743.19 s
#
# Getting coords for 'Lowmoor'; 415/458
#   Lowmoor: (53.8823795, -1.2102841)
#   Time for this location: 2.08 s
#
#   Runtime so far: 745.27 s
#
# Getting coords for 'the Machupa River'; 416/458
#   Location not found: the Machupa River
#   Time for this location: 1.95 s
#
#   Runtime so far: 747.21 s
#
# Getting coords for 'Antofogasta'; 417/458
#   Antofogasta: (-29.6915431, -53.7925858)
#   Time for this location: 0.96 s
#
#   Runtime so far: 748.18 s
#
# Getting coords for 'Corralinha'; 418/458
#   Location not found: Corralinha
#   Time for this location: 2.01 s
#
#   Runtime so far: 750.18 s
#
# Getting coords for 'LONDON'; 419/458
#   LONDON: (51.5074456, -0.1277653)
#   Time for this location: 2.05 s
#
#   Runtime so far: 752.23 s
#
# Getting coords for 'El Ingenio'; 420/458
#   El Ingenio: (-14.6451139, -75.0583569)
#   Time for this location: 2.05 s
#
#   Runtime so far: 754.28 s
#
# Getting coords for 'Tarapaya'; 421/458
#   Tarapaya: (-19.4749313, -65.7981713)
#   Time for this location: 0.92 s
#
#   Runtime so far: 755.20 s
#
# Getting coords for 'Buenos Ayres'; 422/458
#   Buenos Ayres: (-34.6083696, -58.4440583)
#   Time for this location: 1.99 s
#
#   Runtime so far: 757.19 s
#
# Getting coords for 'Tijamuchi'; 423/458
#   Tijamuchi: (-15.1632474, -65.4227211)
#   Time for this location: 0.99 s
#
#   Runtime so far: 758.18 s
#
# Getting coords for 'Huanchaca'; 424/458
#   Huanchaca: (-20.3164904, -66.6833987)
#   Time for this location: 1.00 s
#
#   Runtime so far: 759.18 s
#
# Getting coords for 'Lake Valencia'; 425/458
#   Lake Valencia: (34.8625828, -92.403154)
#   Time for this location: 2.03 s
#
#   Runtime so far: 761.20 s
#
# Getting coords for 'posada'; 426/458
#   posada: (40.631969, 9.716437)
#   Time for this location: 3.12 s
#
#   Runtime so far: 764.32 s
#
# Getting coords for 'Villa Bella'; 427/458
#   Villa Bella: (-20.266642, -43.9486724)
#   Time for this location: 0.91 s
#
#   Runtime so far: 765.23 s
#
# Getting coords for 'The Falls of Theotonio'; 428/458
#   Location not found: The Falls of Theotonio
#   Time for this location: 2.06 s
#
#   Runtime so far: 767.28 s
#
# Getting coords for 'Machacamarca'; 429/458
#   Machacamarca: (-16.3603263, -68.4519815)
#   Time for this location: 0.90 s
#
#   Runtime so far: 768.18 s
#
# Getting coords for 'Cachimayo'; 430/458
#   Cachimayo: (-13.475679, -72.0694716)
#   Time for this location: 2.07 s
#
#   Runtime so far: 770.25 s
#
# Getting coords for 'the Desert of Atacama'; 431/458
#   Location not found: the Desert of Atacama
#   Time for this location: 2.05 s
#
#   Runtime so far: 772.30 s
#
# Getting coords for 'Arepucho'; 432/458
#   Arepucho: (-17.3770946, -65.2229029)
#   Time for this location: 0.92 s
#
#   Runtime so far: 773.22 s
#
# Getting coords for 'Delaware'; 433/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 776.38 s
#
# Getting coords for 'River Piray'; 434/458
#   River Piray: (-16.8693785, -63.497921)
#   Time for this location: 0.83 s
#
#   Runtime so far: 777.21 s
#
# Getting coords for 'San Antonio'; 435/458
#   San Antonio: (29.4246002, -98.4951405)
#   Time for this location: 2.06 s
#
#   Runtime so far: 779.26 s
#
# Getting coords for 'El Rio de Azufre'; 436/458
#   El Rio de Azufre: (38.4538506, -0.4847134)
#   Time for this location: 2.05 s
#
#   Runtime so far: 781.31 s
#
# Getting coords for 'Blanco'; 437/458
#   Blanco: (30.2419274, -98.4004594)
#   Time for this location: 0.89 s
#
#   Runtime so far: 782.20 s
#
# Getting coords for 'Lagunillas'; 438/458
#   Lagunillas: (21.5979815, -99.6193264)
#   Time for this location: 2.00 s
#
#   Runtime so far: 784.20 s
#
# Getting coords for 'Piray'; 439/458
#   Piray: (-18.3365803, -63.1956557)
#   Time for this location: 1.00 s
#
#   Runtime so far: 785.20 s
#
# Getting coords for 'MADEIRA RIVERS'; 440/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 788.35 s
#
# Getting coords for 'Lina Tambo'; 441/458
#   Lina Tambo: (13.9409573, 121.1466965)
#   Time for this location: 0.94 s
#
#   Runtime so far: 789.30 s
#
# Getting coords for 'Chiquitos'; 442/458
#   Chiquitos: (-17.8398242, -61.1461274)
#   Time for this location: 0.92 s
#
#   Runtime so far: 790.22 s
#
# Getting coords for 'Vilcapujio'; 443/458
#   Vilcapujio: (-32.764402, -60.7401192)
#   Time for this location: 2.05 s
#
#   Runtime so far: 792.27 s
#
# Getting coords for 'Tunari'; 444/458
#   Tunari: (45.1327293, 25.467347)
#   Time for this location: 1.95 s
#
#   Runtime so far: 794.21 s
#
# Getting coords for 'Rio Janeiro'; 445/458
#   Geocoder is unavailable
#   Time for this location: 3.16 s
#
#   Runtime so far: 797.37 s
#
# Getting coords for 'Lake Titicaca'; 446/458
#   Lake Titicaca: (-15.9157533, -69.2929572)
#   Time for this location: 0.81 s
#
#   Runtime so far: 798.18 s
#
# Getting coords for 'Bandiola'; 447/458
#   Location not found: Bandiola
#   Time for this location: 2.07 s
#
#   Runtime so far: 800.25 s
#
# Getting coords for 'Pao Grande'; 448/458
#   Pao Grande: (-20.2479371, -42.1457938)
#   Time for this location: 3.05 s
#
#   Runtime so far: 803.30 s
#
# Getting coords for 'San Mateo'; 449/458
#   San Mateo: (37.496904, -122.3330573)
#   Time for this location: 0.98 s
#
#   Runtime so far: 804.28 s
#
# Getting coords for 'Salt Lake City'; 450/458
#   Salt Lake City: (40.7596198, -111.886797)
#   Time for this location: 0.92 s
#
#   Runtime so far: 805.20 s
#
# Getting coords for 'Arica'; 451/458
#   Arica: (-18.4785288, -70.3211394)
#   Time for this location: 2.03 s
#
#   Runtime so far: 807.23 s
#
# Getting coords for 'San Joaquin'; 452/458
#   San Joaquin: (37.9372901, -121.2773719)
#   Time for this location: 2.01 s
#
#   Runtime so far: 809.24 s
#
# Getting coords for 'Cochi-janchi'; 453/458
#   Location not found: Cochi-janchi
#   Time for this location: 0.95 s
#
#   Runtime so far: 810.19 s
#
# Getting coords for 'Piedras de     Uruás'; 454/458
#   Geocoder is unavailable
#   Time for this location: 3.15 s
#
#   Runtime so far: 813.34 s
#
# Getting coords for 'Masa'; 455/458
#   Masa: (44.0359323, 10.1395519)
#   Time for this location: 1.03 s
#
#   Runtime so far: 814.37 s
#
# Getting coords for 'the Province of Matto Grosso'; 456/458
#   Location not found: the Province of Matto Grosso
#   Time for this location: 0.91 s
#
#   Runtime so far: 815.28 s
#
# Getting coords for 'Truxillo'; 457/458
#   Truxillo: (37.3709839, -78.0416682)
#   Time for this location: 0.90 s
#
#   Runtime so far: 816.18 s
#
# Getting coords for 'Rome'; 458/458
#   Geocoder is unavailable
#   Time for this location: 3.17 s
#
#   Runtime so far: 819.35 s
#
# Total time for all locations: 819.35 s

# %%
with open("data/processed/coords.json", "r") as f:
    coords_dict = json.load(f)

# %%
# Load Amazonia boundary
amazon_gdf = gpd.read_file('data/raw/Amazonia-sensu-stricto.gpkg')
amazon_geom = amazon_gdf.unary_union  # Combine all shapes into one MultiPolygon/Polygon
# Out:
# /var/folders/55/3_yjz_1s37vcxh8ld7nlc8k00000gn/T/ipykernel_42797/3401210326.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   amazon_geom = amazon_gdf.unary_union  # Combine all shapes into one MultiPolygon/Polygon

# %%
from shapely.geometry import Point

filtered_coords = {}
for place, (lat, lon) in coords_dict.items():
    point = Point(lon, lat)  # Note (lon, lat) order!
    if amazon_geom.contains(point):
        filtered_coords[place] = (lat, lon)

# %%
# row = df_blocks[df_blocks["location"]=="shaly"]
# sentence = row["sentence_block"]
# print(sentence)

# %%
with open(PATH_TO_COORDS_JSON, "w") as f:
    json.dump(coords_dict, f, indent=4)

# with open("data/processed/coords_v01.json", "r") as file:
#     coords_dict = json.load(file)

# %%
coords_dict
# Out:
# {'Mamoré': [-13.4129427, -65.2152448],
#  'COCHABAMBA': [-17.4012458, -66.1675681],
#  'Venezuela': [8.0018709, -66.1109318],
#  'the Rio Grande': [42.4891061, -2.4409022],
#  'Australia': [-24.7761086, 134.755],
#  'Madeira': [32.7517501, -16.9817487],
#  'Desaguadero': [-16.564809, -69.0401545],
#  'Lima': [-12.0621065, -77.0365256],
#  'Panamá': [8.559559, -81.1308434],
#  'Andean': [42.9414286, -7.9979985],
#  'Sepulturas': [-17.9769226, -67.0134118],
#  'Mollendo': [-17.0292533, -72.0155447],
#  'Columbus': [39.9622601, -83.0007065],
#  'Girão': [32.7351665, -17.1952761],
#  'Minas Maio': [-20.316193, -40.4387467],
#  'China': [35.0000663, 104.999955],
#  'Gurupá': [-1.406325, -51.6427456],
#  'Praia': [14.9162811, -23.5095095],
#  'United States': [39.7837304, -100.445882],
#  'Madeira Rivers': [-6.8064866, -62.4115491],
#  'St. James': [39.573173, -77.7493708],
#  'CARIPUNAS': [-9.2149237, -64.6514359],
#  'Yotala': [-19.1616017, -65.2647648],
#  'Santa Cruz de la Sierra': [-17.7834217, -63.1820853],
#  'Caracas': [10.5060934, -66.9146008],
#  'Mont Alegre': [39.6847152, -0.4251072],
#  'Borja': [41.8348235, -1.5337542],
#  'Mojeño': [-14.8781418, -65.5272056],
#  'Rio Grande': [29.74434, -102.67467],
#  'Chimoré': [-16.9939202, -65.1504578],
#  'Araras': [-22.3569192, -47.3838766],
#  'Ribeirão': [-8.5066761, -35.3747339],
#  'Misque': [-37.1616846, -72.4707556],
#  'Andes': [5.6555942, -75.8778448],
#  'Quevedo': [-1.0669701, -79.4776812],
#  'UT': [39.4225192, -111.714358],
#  'Beni': [9.5293472, 2.2584408],
#  'Masa Cruz': [41.6539246, -4.7219655],
#  'Santa Ana—“Mani': [-2.8876186, -79.0325895],
#  'Payta': [19.4926425, -99.1337776],
#  'the United States': [47.8291375, -122.5970742],
#  'Sancho Mundo': [26.9452559, -105.7054322],
#  'Jamaica': [18.1850507, -77.3947693],
#  'Bananeiras': [-6.7537682, -35.6338343],
#  'Sajáma': [-18.108263, -68.6023775],
#  'Hindostan': [22.3511148, 78.6677428],
#  'Totora': [-6.4927301, -77.4719348],
#  'Quebrada Honda': [10.1875824, -85.297654],
#  'Larati': [-17.3442383, -66.0119337],
#  'Europe': [51.0, 10.0],
#  'Rio de la Plata': [-35.13352, -56.2743702],
#  'Colon': [41.2974531, -96.6094912],
#  'London': [51.5074456, -0.1277653],
#  'Cobija': [-11.0184614, -68.7538149],
#  'Pisco': [-13.7099813, -76.2029793],
#  'Eastern Bolivia': [45.4211595, -75.6970477],
#  'France': [46.603354, 1.8883335],
#  'Tarata': [-17.3983215, -69.9913225],
#  'Punata': [-17.5926818, -65.8496605],
#  'Cavinas': [-12.6272626, -66.770274],
#  'Vio': [42.9086546, 12.9191449],
#  'Plymouth': [50.3714122, -4.1424451],
#  'Choro': [-4.8435726, -39.1393071],
#  'Chapari': [24.8625456, 87.6380734],
#  'Itonama': [-12.9664704, -63.4872592],
#  'Poplar': [51.5110713, -0.0144629],
#  'Corrientes': [-28.9956512, -57.812458],
#  'Chili': [-31.7613365, -71.3187697],
#  'Macacos': [-23.5001413, -48.1908444],
#  'Matto Grosso': [-15.269921, -66.769053],
#  'Santarem': [39.2363637, -8.6867081],
#  'Tarija': [-21.583333, -63.833333],
#  'the Province': [35.6023347, -77.3695595],
#  'the Lower Madeira': [50.7578962, -1.5392597],
#  'Trinidad': [10.4430243, -61.2613054],
#  'England': [52.5310214, -1.2649062],
#  'the “Street of the Shore': [55.9749858, -3.1668986],
#  'Izozo': [-17.2357172, -64.5224947],
#  'Pará': [-6.8699697, -75.0458515],
#  'Copiapo': [-27.3664685, -70.3322753],
#  'farinha': [-5.3879592, -45.418489],
#  'La     ': [20.0171109, 103.378253],
#  'Machupa': [-6.169784, 39.211856],
#  'Mojos': [-14.9961581, -65.641067],
#  'Caracoles': [-34.421071, -70.9391069],
#  'Yungas': [-16.3997857, -72.1648294],
#  'the West Indies': [50.836359, 0.4617891],
#  'Aymará': [-34.5852492, -58.380157],
#  'Cayubaba': [-13.3195647, -65.2507884],
#  'Obidos': [39.3619514, -9.157153],
#  'Manicoré': [-5.804618, -61.289483],
#  'Tacora': [-19.8744967, -66.2268456],
#  'AMAZON': [-0.6207328, -51.5756469],
#  'Great Britain': [54.3151594, -1.9181532],
#  'Exaltacion': [-11.7890104, -66.9367974],
#  'BOLIVIA': [-17.0568696, -64.9912286],
#  'Maravilla': [34.0332976, -118.1681507],
#  'Caripuna': [-23.2971765, -46.0387037],
#  'Misericordia': [38.7114084, -9.1507477],
#  'El Cerro del Volcan': [13.5402156, -86.2128568],
#  'Cerrito': [-31.8546304, -52.8151659],
#  'San Ignacio': [-5.1243684, -78.8956299],
#  'Plate': [53.5499214, 11.4999932],
#  'Coni': [44.4580703, 7.5581367],
#  'Arequipa': [-16.3988667, -71.5369607],
#  'Apolobamba': [-15.0237542, -68.9035868],
#  'Pocona': [-17.6747701, -65.4199602],
#  'Atlantic': [39.5143268, -74.6632883],
#  'Manáos': [-3.1316333, -59.9825041],
#  'Curahuara': [-17.6322495, -67.986774],
#  'Borba': [38.8057942, -7.4542105],
#  'Paz': [45.2908372, 14.0944912],
#  'Silver Hill': [38.839849, -76.9381785],
#  'the Madeira and': [51.6064776, -0.5563306],
#  'CHUQUISACA': [-19.0477251, -65.2594306],
#  'Catamarca': [-27.1910825, -67.105374],
#  'Gran Chaco': [-20.0976312, -59.8739161],
#  'Cuatro Ojos': [41.6921754, -3.9773195],
#  'Merim': [42.0467658, -8.4003247],
#  'Japan': [36.5748441, 139.2394179],
#  'Rapids': [43.0957985, -78.6545955],
#  'Maddalena': [45.0293003, 7.3023687],
#  'San Francisco': [37.7792588, -122.4193286],
#  'Matto': [36.5266411, 136.5661935],
#  'Curumbá': [-23.3496199, -47.6303565],
#  'Liverpool': [53.4071991, -2.99168],
#  'Yocalla': [-19.3888592, -65.9112948],
#  'La Cruz': [11.0088428, -85.5518491],
#  'Valparaiso': [41.4672552, -87.0604487],
#  'the Atlantic Ocean': [62.46558, 6.0960324],
#  'San Nicolas': [16.0703505, 120.7624714],
#  'Catariri': [-19.7357903, -66.9563811],
#  'Paraguay': [-23.3165935, -58.1693445],
#  'the Black Country': [52.5215006, -2.0766606],
#  'Tacna': [-18.01386, -70.2511032],
#  'La Barca': [44.083538, 10.4444778],
#  'Argentine': [-34.9964963, -64.9672817],
#  'San José': [37.3361663, -121.890591],
#  'Canichana': [-14.1817047, -65.0243059],
#  'Deseada': [28.5692311, -17.8372084],
#  'Maury': [35.6285992, -87.0736684],
#  'Spain': [39.3260685, -4.8379791],
#  'Chuquisaca': [-19.0477251, -65.2594306],
#  'Birkenhead': [53.3895177, -3.0248007],
#  'Apiri': [1.7851613, 33.4015272],
#  'Peru': [-6.8699697, -75.0458515],
#  'Las Tetillas': [12.5284007, -86.238356],
#  'Curahuara de Carangas': [-17.8426585, -68.4089744],
#  'Amazon': [-0.6207328, -51.5756469],
#  'Valle Grande': [-23.4767516, -64.9460176],
#  'Pamas': [-2.8507408, -78.337884],
#  'Calamarca': [-8.1700672, -78.4115144],
#  'Pachia': [45.8253865, 26.1180463],
#  'Guajarás': [36.9123213, -3.7450558],
#  'Vacas': [18.153532, -66.4756856],
#  'Orinoco': [7.6328194, -64.8599339],
#  'U.S.': [39.7837304, -100.445882],
#  'Poopo': [-18.2505991, -66.9746906],
#  'Southampton': [50.9025349, -1.404189],
#  'New York': [40.7127281, -74.0060152],
#  'Guasu': [54.3151594, -1.9181532],
#  'Pacific': [46.5334929, -123.768029],
#  'Titicaca': [-15.7334907, -69.9357769],
#  'Maués': [-3.3795798, -57.7196072],
#  'SAN ANTONIO': [29.4246002, -98.4951405],
#  'Calcutta': [22.5726459, 88.3638953],
#  'Breves': [-1.68036, -50.479085],
#  'TACORA': [-19.8744967, -66.2268456],
#  'San Ramon': [37.7648021, -121.9544387],
#  'Layes': [42.4127663, -0.4216246],
#  'Sahama': [-13.24, 15.359167],
#  'San Louise': [34.7363227, 135.5097558],
#  'Paredão': [-19.21701, -45.2065915],
#  'Santa Ana': [33.7494951, -117.873221],
#  'Tombs': [27.6637328, 30.9276322],
#  'Republic': [39.8266503, -97.6580834],
#  'Lomas': [42.27354, -4.5503861],
#  'Rabo': [5.301701, 95.5928614],
#  'charqui': [-3.3461686, -79.0312353],
#  'Crato': [-7.2369112, -39.4149236],
#  'Securé': [-16.1735801, -65.838946],
#  'Diaz Gana': [-23.665188, -70.3949972],
#  'West End': [35.9099875, -79.0752876],
#  'Serpa': [37.9436517, -7.5966902],
#  'El Cerrito': [37.9154056, -122.301411],
#  'Patagonia': [31.5402016, -110.753927],
#  'Cordillera': [17.3597101, 121.0716923],
#  'Cerro': [42.2977315, 13.4958871],
#  'Atacama': [-24.5563029, -69.4226479],
#  'Tolapalca': [-16.0099371, -70.665549],
#  'Callao': [-12.0864633, -77.2234463],
#  'Inca Corral': [-17.4222312, -65.9482004],
#  'Reyes': [-14.2952193, -67.335855],
#  'Las Siete     ': [28.3473425, -16.8928153],
#  'San Pedro': [33.7358518, -118.2922934],
#  'South America': [-21.0002179, -61.0006565],
#  'Otuquis': [-19.609404, -58.2894017],
#  'Pilcomayo': [-12.0493725, -75.2504039],
#  'Merceditas': [23.0595224, -82.293862],
#  'The San Antonio': [43.2533477, -2.8840011],
#  'Western Brazil': [-0.1813973, 30.3640168],
#  'LIVERPOOL': [53.4071991, -2.99168],
#  'Oliden': [-35.1843158, -57.9486525],
#  'Alto Peru': [-8.9492072, -78.5798997],
#  'Yuracaré': [-16.8928688, -64.7962327],
#  'Prado': [41.9203967, -5.4203949],
#  'Chocos': [-12.927275, -75.9143335],
#  'SUCRE': [-19.0477251, -65.2594306],
#  'Calderão': [-8.7071664, -36.2583471],
#  'Espiritu Santo': [-15.1563411, 167.0510705],
#  'Portugal': [39.6621648, -8.1353519],
#  'Oruro': [-18.666667, -67.666667],
#  'Cinti': [39.1014537, -84.5124602],
#  'Cliza': [-17.5918058, -65.9341813],
#  'Bahia Negra': [-20.2308712, -58.1690716],
#  'Canto Molino': [43.266554, -5.7439882],
#  'Umaitá': [-12.0070525, -68.231074],
#  'Manchester': [53.4794892, -2.2451148],
#  'Mont     ': [47.3752671, -109.638757],
#  'Morinhos': [-5.8229709, -47.0732895],
#  'Chilon': [40.738034, 72.517889],
#  'Angostura': [8.1028532, -63.5469562],
#  'Tuy': [42.0501375, -8.6466411],
#  'Islay': [55.7585802, -6.1656723],
#  'Guaporé': [-28.8471928, -51.8907881],
#  'Palca': [-16.5611164, -67.9530221],
#  'Sandia': [-13.833333, -69.333333],
#  'Taboga': [8.7895216, -79.56074],
#  'San Borja': [-12.107075, -76.9988421],
#  'Blanco River': [29.9912476, -98.094547],
#  'the Rio Negro': [37.7527574, -0.8423281],
#  'Purus': [-7.5658532, -66.4654237],
#  'San     ': [7.0000085, -73.2500086],
#  'Old England': [50.8428356, 4.3590958],
#  'Chinguri': [-18.3840813, -65.2244488],
#  'Yata': [-10.4872569, -65.4357103],
#  'Loreto': [43.439498, 13.6070214],
#  'Bolivia': [-17.0568696, -64.9912286],
#  'Buena Esperanza': [-34.7578641, -65.2535837],
#  'Pederneira': [39.6029108, -9.0701572],
#  'Caupolican': [-2.8946801, -78.9762521],
#  'San Pablo': [-23.5506507, -46.6333824],
#  'Central India': [22.5724857, 88.3587427],
#  'Central America': [-30.2928485, 153.1256159],
#  'Mayosa': [-12.5319418, -65.1601508],
#  'Aullagas': [-18.6822248, -65.9974987],
#  'El Cruzero': [11.6944323, -84.4009638],
#  'the East Indies': [52.7295398, -1.7300896],
#  'the Pacific coast': [38.0186902, -122.7298682],
#  'Bartolo': [18.2011587, -66.8503643],
#  'Cerro de Potosí': [25.6607879, -100.4398121],
#  'Cavalho Marinho': [-16.4921664, -39.0736868],
#  'Quilpa': [-6.4863107, -76.3594255],
#  'San Carlos': [37.504936, -122.261823],
#  'the Pacific Coast': [38.0186902, -122.7298682],
#  'India': [22.3511148, 78.6677428],
#  'San Simon': [32.2665117, -109.2270613],
#  'Siriono': [-17.3839684, -66.1849123],
#  'Quiroga': [42.4751472, -7.2697796],
#  'Porco': [37.7252547, -7.8304851],
#  'Periquitos': [-22.7799785, -43.3268206],
#  'janchi': [16.913346, 121.7610012],
#  'PERU': [-6.8699697, -75.0458515],
#  'Vermejo': [37.0852054, -116.0538054],
#  'Marmélos': [41.4309748, -7.202133],
#  'Sacába': [-17.320452, -66.0459591],
#  'Cochi': [-33.4356923, -70.6497111],
#  'Tapajoz': [-3.0958776, -60.0583542],
#  'Concepcion de Baures': [-16.5497806, -68.1975537],
#  'Cochabamba': [-17.4012458, -66.1675681],
#  'Pazna': [-18.5974435, -66.9207527],
#  'PARÁ': [-6.8699697, -75.0458515],
#  'Isthmus': [35.9981447, -84.1584272],
#  'ENGLAND': [52.5310214, -1.2649062],
#  'California': [36.7014631, -118.755997],
#  'Hindoo': [49.5548035, -124.9061185],
#  'Isla': [35.887175, 14.517307],
#  'Tucuman': [-26.5643582, -64.882397],
#  'Puno': [-15.0, -70.0],
#  'Callao Bay': [-12.0577778, -77.1552778],
#  'Calara': [6.4517957, 124.790849],
#  'Nazareth': [32.7046364, 35.2971854],
#  'playas': [-2.5937913, -80.4261454],
#  'Yca': [49.6789457, -124.9806989],
#  'Trés Irmãos': [-21.6280789, -41.9884844],
#  'Cristal Maio': [37.1162032, -8.6560299],
#  'Sacta': [-14.2592937, -75.7009502],
#  'Northern Brazil': [-29.8322441, 17.1613977],
#  'Itenez': [-13.3623488, -63.1872093],
#  'Marajo': [-0.9558821, -49.5469438],
#  'Grande': [53.5823287, 10.3863496],
#  'San Xavier': [32.1036996, -111.013981],
#  'Yacuma': [-13.7830746, -65.8903957],
#  'Principe da Beira': [-12.0704497, -64.1866661],
#  'Pachimoco': [-30.1979169, -68.8300915],
#  'Baures': [-13.6546062, -63.6955015],
#  'Brazil': [-10.3333333, -53.2],
#  'Charqui': [-3.3461686, -79.0312353],
#  'Santa Cruz': [28.467178, -16.2507843],
#  'Arani': [-17.5996321, -65.6653538],
#  'the San Jacinto': [14.0726309, 121.3254664],
#  'a “City of Health': [48.508063, 32.2660465],
#  'El Chaco': [-0.2442778, -77.675958],
#  'Mississippi': [32.9715285, -89.7348497],
#  'Aspinwall': [41.9120574, -95.1354782],
#  'Machado': [-21.6762861, -45.9211696],
#  'Cruzero': [-13.3350222, -72.1562292],
#  'Aiquile': [-18.2002218, -65.1806293],
#  'Huata': [-9.0161061, -77.8619114],
#  'Theotonio': [-22.8205701, -43.3616001],
#  'remanso': [-9.6179416, -42.0830557],
#  'Leñas': [-19.2508556, -66.0734544],
#  'Lowmoor': [53.8823795, -1.2102841],
#  'Antofogasta': [-29.6915431, -53.7925858],
#  'LONDON': [51.5074456, -0.1277653],
#  'El Ingenio': [-14.6451139, -75.0583569],
#  'Tarapaya': [-19.4749313, -65.7981713],
#  'Buenos Ayres': [-34.6083696, -58.4440583],
#  'Tijamuchi': [-15.1632474, -65.4227211],
#  'Huanchaca': [-20.3164904, -66.6833987],
#  'Lake Valencia': [34.8625828, -92.403154],
#  'posada': [40.631969, 9.716437],
#  'Villa Bella': [-20.266642, -43.9486724],
#  'Machacamarca': [-16.3603263, -68.4519815],
#  'Cachimayo': [-13.475679, -72.0694716],
#  'Arepucho': [-17.3770946, -65.2229029],
#  'River Piray': [-16.8693785, -63.497921],
#  'San Antonio': [29.4246002, -98.4951405],
#  'El Rio de Azufre': [38.4538506, -0.4847134],
#  'Blanco': [30.2419274, -98.4004594],
#  'Lagunillas': [21.5979815, -99.6193264],
#  'Piray': [-18.3365803, -63.1956557],
#  'Lina Tambo': [13.9409573, 121.1466965],
#  'Chiquitos': [-17.8398242, -61.1461274],
#  'Vilcapujio': [-32.764402, -60.7401192],
#  'Tunari': [45.1327293, 25.467347],
#  'Lake Titicaca': [-15.9157533, -69.2929572],
#  'Pao Grande': [-20.2479371, -42.1457938],
#  'San Mateo': [37.496904, -122.3330573],
#  'Salt Lake City': [40.7596198, -111.886797],
#  'Arica': [-18.4785288, -70.3211394],
#  'San Joaquin': [37.9372901, -121.2773719],
#  'Masa': [44.0359323, 10.1395519],
#  'Truxillo': [37.3709839, -78.0416682]}

# %%
df_blocks.columns
# Out:
# Index(['location', 'sentence_block', 'start_word_index', 'end_word_index',
#        'location_start_char', 'location_end_char'],
#       dtype='object')

# %%
# Each location can have multiple blocks, so grab the first one or join with separator
location_to_sentence = (
    df_blocks
    .groupby("location")["sentence_block"]
    .apply(lambda x: "<br><br>".join(x))
    .to_dict()
)

# %%
# Now, create a Folium map centered somewhere (e.g., the average of your lat/lon)
if filtered_coords:
    lats = [coords[0] for coords in filtered_coords.values()]
    lons = [coords[1] for coords in filtered_coords.values()]
    avg_lat = sum(lats) / len(lats)
    avg_lon = sum(lons) / len(lons)
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=2)
else:
    m = folium.Map(location=[0, 0], zoom_start=2)  # fallback

# Add markers
for name, coords in filtered_coords.items():
    popup_text = location_to_sentence.get(name, name)  # fallback to name

    folium.Marker(
        location=coords,
        popup=folium.Popup(popup_text, max_width=350),  # max_width avoids very wide popups
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f2ec5342964057de77749a50d3a7e4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f2ec5342964057de77749a50d3a7e4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f2ec5342964057de77749a50d3a7e4c = L.map(
#                 &quot;map_7f2ec5342964057de77749a50d3a7e4c&quot;,
#                 {
#                     center: [-10.306687446666666, -64.39436644888889],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7459404a13dc47660257d258f6845b7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7459404a13dc47660257d258f6845b7c.addTo(map_7f2ec5342964057de77749a50d3a7e4c);
#
#
#             var marker_5aadca0d0ab04c2db711c51507708617 = L.marker(
#                 [-13.4129427, -65.2152448],
#                 {
# }
#             ).addTo(map_7f2ec5342964057de77749a50d3a7e4c);
#
#
#             var icon_ba9283ffa9099b3399e0da141153d6f1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3cfd93a2bd40e5362b99609ee0343391 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_3b5419e855a3289e87764ffe22e9b27f = $(`&lt;div id=&quot;html_3b5419e855a3289e87764ffe22e9b27f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;phosphorescent fire, and it appeared as though we were steaming through a sea of flaming spirits. The mouth of the river Amazon has many shifting banks and reefs of which no accurate information exists, and vessels are frequently lost in attempting to get up to Pará without a pilot. In 1873, three vessels, laden with iron for the Madeira and &lt;&lt;Mamoré&gt;&gt; railway, were lost, one after another, on the reefs near the Braganza lightship, which had shifted from her moorings and remained away from her station for many months. More pilots are required at the station of Salinas, for it has often happened that captains of vessels have got tired of beating about, waiting for a pilot to come off, and&lt;br&gt;&lt;br&gt;how shot—Onças, and other animals—Birds, wild turkeys, ducks, etc.—Insects, mosquitoes, ants, etc.—Snakes, etc., etc. From San Antonio the railway commences that is in course of construction by the Madeira and &lt;&lt;Mamoré&gt;&gt; Railway Company. This line, which is to run upon the eastern side of the rapids, has for its object the establishment of communication between the navigable waters of the Mamoré and Guaporé or Itenez in Eastern Bolivia, and the Madeira and Amazon in Northern Brazil. The length of the line will be about 180 miles, and it is estimated to cost £6000 per mile, with a metre gauge. At foot of the rapid of San Antonio the river forms a bay on the right or eastern bank of the river,&lt;br&gt;&lt;br&gt;will now be the best plan to copy the notes I then entered in my diary, in order that the rapids and other portions of the route travelled over may be described in proper order. [Illustration: GARITEA, OR TRAVELLER’S CANOE, RIVER MADEIRA.] But, first, it is necessary to describe the arrangements requisite for the ascent of the rapids and the &lt;&lt;Mamoré&gt;&gt; to the most eastern towns of Bolivia. Large canoes, called on the river “batelãos,” or “igariteas,” are the craft required, a good and useful one being from eight to ten yards in length, by about four or five feet beam; they draw from two to four feet of water, and will carry from three to six tons. A crew of&lt;br&gt;&lt;br&gt;principal fall, and from this circumstance the fall has been named the “Cachuela de Madeira,” as below the junction the Madeira River is said to commence. From the junction of the Beni to that of the Itenez, the river is by some called the Rio Grande, by others the Itenez, and it is only above the latter junction that the &lt;&lt;Mamoré&gt;&gt; reigns. Above the Madeira Fall, and in the neighbourhood of the junction of the Beni, the river is much broken up by islands, and consequently the navigation of this stretch is almost, if not quite, as bad as that of the “Rabo do Ribeirão.” At the junction of the river Beni, the river appears as though it divided itself into&lt;br&gt;&lt;br&gt;I fancy that it is better at low water, for the channels then would be better defined: now the channels are amongst rocks, and very difficult to find an

# %%
# Now, create a Folium map centered somewhere (e.g., the average of your lat/lon)
if filtered_coords:
    lats = [coords[0] for coords in filtered_coords.values()]
    lons = [coords[1] for coords in filtered_coords.values()]
    avg_lat = sum(lats) / len(lats)
    avg_lon = sum(lons) / len(lons)
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=2)
else:
    m = folium.Map(location=[0, 0], zoom_start=2)  # fallback
    
# Number of words in the whole book
total_words = len(words)

def first_N_words(text, N=6):
    tokens = text.split()
    preview = " ".join(tokens[:N])
    return preview + ("..." if len(tokens) > N else "")

# Group all sentence blocks per location, keeping their start_word_index for sorting %age
blocks_grouped = df_blocks.groupby("location").apply(
    lambda df: df.sort_values('start_word_index')[['sentence_block', 'start_word_index']].to_dict('records')
)
# blocks_grouped is now a Series: location -> list of dicts with sentence_block, start_word_index

# Now make what you want for the popup!
location_to_sentence = {}
for loc, entries in blocks_grouped.items():
    popup_parts = []
    for i, entry in enumerate(entries):
        pct_through = 100 * entry['start_word_index'] / total_words
        pct_str = f"<b>{pct_through:.1f}% through book</b>: "
        if i == 0:
            popup_parts.append(f'{pct_str}<span>{entry["sentence_block"]}</span>')
        else:
            short_line = first_N_words(entry["sentence_block"], N=7)
            popup_parts.append(f'{pct_str}<i>{short_line}</i>')
    # Separate blocks by lines
    popup_text = "<hr>".join(popup_parts)
    location_to_sentence[loc] = popup_text

# Use with folium as before:
for name, coords in filtered_coords.items():
    folium.Marker(
        location=coords,
        popup=folium.Popup(location_to_sentence.get(name, name), max_width=350),
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)
# Out:
# /var/folders/55/3_yjz_1s37vcxh8ld7nlc8k00000gn/T/ipykernel_42797/1904542715.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   blocks_grouped = df_blocks.groupby("location").apply(

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2920df31fa7947f45ba8bf66cf48d4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2920df31fa7947f45ba8bf66cf48d4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2920df31fa7947f45ba8bf66cf48d4f = L.map(
#                 &quot;map_d2920df31fa7947f45ba8bf66cf48d4f&quot;,
#                 {
#                     center: [-10.306687446666666, -64.39436644888889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3676527962a114446d744fe707aa8154 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2920df31fa7947f45ba8bf66cf48d4f);
#
#
#             var marker_512d0a7825e260c455521e00278100b6 = L.marker(
#                 [-13.4129427, -65.2152448],
#                 {}
#             ).addTo(map_d2920df31fa7947f45ba8bf66cf48d4f);
#
#
#             var icon_a235ee9f24cf7695b956f1dc9b9e3201 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_512d0a7825e260c455521e00278100b6.setIcon(icon_a235ee9f24cf7695b956f1dc9b9e3201);
#
#
#         var popup_deee8a4dd8bc72b69b19bc18d45fa053 = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var html_be0f1344649c0deabbc39d38d85fd007 = $(`&lt;div id=&quot;html_be0f1344649c0deabbc39d38d85fd007&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;0.5% through book&lt;/b&gt;: &lt;span&gt;phosphorescent fire, and it appeared as though we were steaming through a sea of flaming spirits. The mouth of the river Amazon has many shifting banks and reefs of which no accurate information exists, and vessels are frequently lost in attempting to get up to Pará without a pilot. In 1873, three vessels, laden with iron for the Madeira and &lt;&lt;Mamoré&gt;&gt; railway, were lost, one after another, on the reefs near the Braganza lightship, which had shifted from her moorings and remained away from her station for many months. More pilots are required at the station of Salinas, for it has often happened that captains of vessels have got tired of beating about, waiting for a pilot to come off, and&lt;/span&gt;&lt;hr&gt;&lt;b&gt;5.3% through book&lt;/b&gt;: &lt;i&gt;how shot—Onças, and other animals—Birds, wild turkeys,...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;7.5% through book&lt;/b&gt;: &lt;i&gt;will now be the best plan to...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;19.4% through book&lt;/b&gt;: &lt;i&gt;principal fall, and from this circumstance the...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;19.7% through book&lt;/b&gt;: &lt;i&gt;I fancy that it is better at...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;24.6% through book&lt;/b&gt;: &lt;i&gt;arose. About 11 a.m. we got in...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;24.6% through book&lt;/b&gt;: &lt;i&gt;a river on the right bank, and...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;24.6% through book&lt;/b&gt;: &lt;i&gt;it for the Itenez; but it turned...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;24.9% through book&lt;/b&gt;: &lt;i&gt;are to-day reckoned with that department. On...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;25.2% through book&lt;/b&gt;: &lt;i&gt;lit fires and cooked the meat, and...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;27.2% through book&lt;/b&gt;: &lt;i&gt;and about 6 p.m., as we came...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;27.2% through book&lt;/b&gt;: &lt;i&gt;been able to have allowed them. June...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;28.4% through book&lt;/b&gt;: &lt;i&gt;declared to belong to the Chacobo tribe...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;28.9% through book&lt;/b&gt;: &lt;i&gt;was certainly a most arduous task, and...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;28.9% through book&lt;/b&gt;: &lt;i&gt;in striking against the numerous rocks amongst...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;29.6% through book&lt;/b&gt;: &lt;i&gt;had been very high, and had consequently...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;29.9% through book&lt;/b&gt;: &lt;i&gt;the delay, and seek a new crew...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;29.9% through book&lt;/b&gt;: &lt;i&gt;forcing them to take me on further....&lt;/i&gt;&lt;hr&gt;&lt;b&gt;29.9% through book&lt;/b&gt;: &lt;i&gt;is a list of the fifteen principal...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;29.9% through book&lt;/b&gt;: &lt;i&gt;which appears to have been one of...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;32.6% through book&lt;/b&gt;: &lt;i&gt;in my service for more than twelve...&lt;/i&gt;&lt;hr&gt;&lt;b&gt;32.8% through book&lt;/b&gt;: &lt;i&gt;of one man and a large canoe....&lt;/i&gt;&lt;hr&gt;&lt;b&gt;32.8% through book&lt;/b&gt;: &lt;i&gt;than thirty feet at top, which was...&lt;/i&gt;&lt;hr&gt;&lt;

# %%
m.save('map_of_locations.html')

# %% [markdown]
# ## Get metadata for each text snippet from openai's api

# %%
with open(".secrets.json", "r") as f:
    OPENAI_API_KEY = (json.load(f))["OPENAI_API_KEY"]
    
client = OpenAI()
client.api_key=OPENAI_API_KEY

response = client.responses.create(
    model="gpt-4.1",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Beneath a shimmering moon, a gentle unicorn named Luna tiptoed through a field of glowing flowers, leaving trails of stardust for dreamers to follow.

# %%
entry
# Out:
# location                                                    Matto Grosso
# sentence_block         ##### FRONTMATTER REDACTED ##### PREFACE. A fe...
# start_word_index                                                      27
# end_word_index                                                        28
# location_start_char                                                  166
# location_end_char                                                    178
# Name: 0, dtype: object

# %%
entry = df_blocks.iloc[100]
pct = 100 * entry['start_word_index'] / total_words

message = f"""
This text is a snippet from the 1879 book 'Up the Amazon and Madeira Rivers through Bolivia and Peru' by 'Edward D. Mathews'. The snippet is centred on the location {entry.location}, which occurs {pct:.2f} % of the way through the book. Please analyse the text with specific reference to this location and give me the following:
- is the author referring to a place he is encountering during his journey in the Amazon? (answer: yes, no, unsure)
- is the author travelling to or from the location? (answer: to, from, neither, unsure)
- what is the authors sentiment to the location? (answer: positive, negative, curious, bored, etc. none, unsure)
- what type of place is this location? (answer: e.g. city, river, region, infrastructure, anything else, unknown)
- is the location real? (answer: yes, no, unsure)
- does the author date (roughly or precisely) this location in their journey? (answer: yes (if so, give date), no, unsure)
- what is the theme of the location? (answer: nature, anthropological, danger, disease, travel, etc. unsure)
- which of these themes best describes the main topic of the following passage? (answer: travel, exploration, trade, health, wildlife, engineering, conflict, etc.)
- identify any major event associated with this location. (answer: illness, accident, meeting, discovery, etc. unsure)
- summary of snippet (answer: 1-2 sentences)
- ambiguity of snippet, what is missing by it being cut off?
- additional places mentioned

Snippet:
{entry['sentence_block']}
"""
print(message)
# Out:
# This text is a snippet from the 1879 book 'Up the Amazon and Madeira Rivers through Bolivia and Peru' by 'Edward D. Mathews'. The snippet is centred on the location Tapajoz, which occurs 2.20 % of the way through the book. Please analyse the text with specific reference to this location and give me the following:
# - is the author referring to a place he is encountering during his journey in the Amazon? (answer: yes, no, unsure)
# - is the author travelling to or from the location? (answer: to, from, neither, unsure)
# - what is the authors sentiment to the location? (answer: positive, negative, curious, bored, etc. none, unsure)
# - what type of place is this location? (answer: e.g. city, river, region, infrastructure, anything else, unknown)
# - is the location real? (answer: yes, no, unsure)
# - does the author date (roughly or precisely) this location in their journey? (answer: yes (if so, give date), no, unsure)
# - what is the theme of the location? (answer: nature, anthropological, danger, disease, travel, etc. unsure)
# - which of these themes best describes the main topic of the following passage? (answer: travel, exploration, trade, health, wildlife, engineering, conflict, etc.)
# - identify any major event associated with this location. (answer: illness, accident, meeting, discovery, etc. unsure)
# - summary of snippet (answer: 1-2 sentences)
# - ambiguity of snippet, what is missing by it being cut off?
#
# Snippet:
# large pampas, on which cattle are reared in great numbers. These “fazendas de ganado,” or cattle-runs, are very valuable properties, especially those that have hilly lands on them, where the cattle can take refuge during the periodical inundations. The fourth day brings the steamer to Santarem, on the <<Tapajoz>> River, a short distance from its junction with the Amazon. The Tapajoz is a fine river of clear darkish-coloured water, very different in appearance to the whitish water of the great river, which always contains a certain amount of sediment. Santarem is a very pretty town of about 3000 or 4000 inhabitants, and is built upon rising ground on the right bank, its fine church showing to great advantage. The climate of

# %%
from openai import OpenAI
from pydantic import BaseModel

class LocationMetadata(BaseModel):
    journey: str | None
    travel_to_from: str | None
    sentiment: str | None
    type: str | None
    real: bool | None
    date: str | None
    theme: str | None
    event: str | None
    summary: str
    ambiguity: str
    plases: list[str]


response = client.responses.parse(
    model="gpt-4.1",
    input=[
        {"role": "system", "content": "You are an expert in 19th century Amazonian exploration."},
        {
            "role": "user",
            "content": message,
        },
    ],
    text_format=LocationMetadata,
)

event = response.output_parsed

# %%
event
# Out:
# LocationMetadata(journey='Yes, the author is describing his journey along the Amazon, encountering the Tapajoz River and its junction with the Amazon.', travel_to_from='to', sentiment='positive', type='river', real=True, date='no', theme='travel', event='unsure', summary='The author describes reaching the Tapajoz River and the town of Santarem, noting the characteristics of the river and the local geography and economy.', ambiguity='The snippet is cut off before providing a full description of Santarem, its church, and possibly more details about the river or surrounding area; it is also not clear how long the author stays or what specific events occur there.', plases=['Tapajoz River', 'Santarem', 'Amazon River'])
